# %%
import numpy as np
import pandas as pd
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.model_selection import StratifiedKFold
# Out:
# Num GPUs Available:  0

# %% [markdown]
# Считаем начальные данные, лучшие фичи, посылку с лучшим скором

# %%
train_df = pd.read_parquet("train_data.pqt")
test_df = pd.read_parquet("test_data.pqt")
best_features = list(pd.read_csv("best_features_optuna.csv").Feature.values)
cluster_weights = pd.read_excel("cluster_weights.xlsx").set_index("cluster")
weights_dict = cluster_weights["unnorm_weight"].to_dict()
best_predictions = pd.read_csv("best_predictions.csv")

cat_cols = [
    "channel_code",
    "city",
    "city_type",
    "okved",
    "segment",
    "start_cluster",
    "index_city_code",
    "ogrn_month",
    "ogrn_year",
]

labels = [
    "{other}",
    "{}",
    "{α, β}",
    "{α, γ}",
    "{α, δ}",
    "{α, ε, η}",
    "{α, ε, θ}",
    "{α, ε, ψ}",
    "{α, ε}",
    "{α, η}",
    "{α, θ}",
    "{α, λ}",
    "{α, μ}",
    "{α, π}",
    "{α, ψ}",
    "{α}",
    "{λ}",
]

# %% [markdown]
# В данных удаляются колонки с >50% пропусками, добавляются к тренировочным данным тестовые, на колторых модель уверенна, применяется обработка lda добавляющая 16 дополнительных признаков

# %%
def extend_test(df):
    ddf = df.sort_values(by=["id", "date"], ascending=True)
    ddf.reset_index(drop=True, inplace=True)
    mask = (ddf["date"] == "month_5") & (ddf["date"].shift(1) == "month_6")
    rows_to_insert = df[mask].copy()
    rows_to_insert["date"] = "month_4"
    ddf = pd.concat([ddf, rows_to_insert], ignore_index=True)
    ddf = ddf.sort_values(by=["id", "date"], ascending=True)
    ddf.reset_index(drop=True, inplace=True)
    return ddf


def prepare_data_for_3m(
    df_train,
    df_test,
    cat_cols,
    nan_process="0",
    drop_lot_nan_cols_thr=0.5,
):
    """
    Operations:
    1. fill na
    2. drop columns with too many nans
    3. delete bad features

    df_train: pd.DataFrame
    df_test: pd.DataFrame
    nan_process: "0" or "mean" or "median" or "999"
    drop_lot_nan_cols_thr: float, 0-1, 1 - no drop, 0 - drop all

    return: pd.DataFrame, pd.DataFrame, list

    """
    df_train["is_train"] = 1
    df_test["is_train"] = 0

    df_concat = pd.concat([df_train, df_test])
    bad_features = df_concat.columns[
        df_concat.isna().sum() > df_concat.shape[0] * drop_lot_nan_cols_thr
    ]

    if nan_process == "999":
        df_concat = df_concat.fillna(-999)

    if nan_process == "0":
        df_concat = df_concat.fillna(0)
    elif nan_process == "mean":
        df_concat = df_concat.fillna(df_concat.mean())
    elif nan_process == "median":
        df_concat = df_concat.fillna(df_concat.median())
    df_concat[cat_cols] = df_concat[cat_cols].astype("category")

    df_concat = df_concat.drop(bad_features, axis=1)
    df_train.drop("is_train", axis=1, inplace=True)
    df_test.drop("is_train", axis=1, inplace=True)

    a = df_concat[df_concat["is_train"] == 1].drop("is_train", axis=1)
    b = df_concat[df_concat["is_train"] == 0].drop(
        ["is_train", "end_cluster"], axis=1
    )

    return (
        a,
        b,
        list(set(cat_cols).intersection(a.columns)),
    )


def concatenate_months(df_train, df_test, cat_cols):
    """Concatenate data across months"""
    df_train = df_train.sort_values(by=["id", "date"], ascending=True)
    df_test = df_test.sort_values(by=["id", "date"], ascending=True)

    cat_cols_3 = (
        [f"{i}_1" for i in cat_cols]
        + [f"{i}_2" for i in cat_cols]
        + [f"{i}_3" for i in cat_cols]
    )

    concatenated_train = pd.DataFrame()
    concatenated_test = pd.DataFrame()

    concatenated_train["end_cluster"] = df_train["end_cluster"][
        df_train["date"] == "month_3"
    ].reset_index(drop=True)

    for i, month in enumerate(["month_1", "month_2", "month_3"]):
        data = (
            df_train[df_train["date"] == month]
            .drop(["date", "id", "end_cluster"], axis=1)
            .reset_index(drop=True)
        )
        data.columns = [f"{col}_{i+1}" for col in data.columns]
        concatenated_train = pd.concat([concatenated_train, data], axis=1)

    for i, month in enumerate(["month_4", "month_5", "month_6"]):

        data = (
            df_test[df_test["date"] == month]
            .drop(["date", "id"], axis=1)
            .reset_index(drop=True)
        )
        data.columns = [f"{col}_{i+1}" for col in data.columns]
        concatenated_test = pd.concat([concatenated_test, data], axis=1)

    assert concatenated_train.shape[1] == concatenated_test.shape[1] + 1
    assert (
        concatenated_train.columns[1:] == concatenated_test.columns
    ).sum() == concatenated_test.shape[1]
    return concatenated_train, concatenated_test, cat_cols_3


def extract_optuna_features(df):
    if "end_cluster" in df.columns:
        return df[list(a.columns.intersection(best_features)) + ["end_cluster"]]
    else:
        return df[list(a.columns.intersection(best_features))]


def aug_train_from_test(train, test, thr=0.9):
    sub_df = test[best_predictions.drop(["id"], axis=1).max(axis=1) > thr]
    sub_df.insert(
        1,
        "end_cluster",
        best_predictions[
            best_predictions.drop(["id"], axis=1).max(axis=1) > thr
        ]
        .drop(["id"], axis=1)
        .idxmax(axis=1),
    )

    return pd.concat([train, sub_df])


test_df = extend_test(test_df)
a, b, c = concatenate_months(train_df, test_df, cat_cols)
train_df_3m, test_df_3m, cat_cols_3m = prepare_data_for_3m(
    a, b, c, nan_process="999"
)
train_df_3m.drop("start_cluster_3", axis=1, inplace=True)
test_df_3m.drop("start_cluster_3", axis=1, inplace=True)
cat_cols_3m.remove("start_cluster_3")
# start_cluster_3 удаляется так как в тесте он почти везде пропущен

train_df_3m = aug_train_from_test(train_df_3m, test_df_3m, 0.9)

# %%
def add_lda(numeric_train, target, numeric_test, train, test):
    scaler = StandardScaler()
    scaler.fit(pd.concat([numeric_train, numeric_test]))
    X_train_scaled = scaler.transform(numeric_train)
    X_test_scaled = scaler.transform(numeric_test)
    lda = LinearDiscriminantAnalysis(n_components=target.unique().shape[0] - 1)
    lda.fit(X_train_scaled, target)

    train_lda = lda.transform(X_train_scaled)
    test_lda = lda.transform(X_test_scaled)

    train_lda = pd.DataFrame(
        train_lda,
        columns=[f"lda_{i}" for i in range(target.unique().shape[0] - 1)],
        index=train.index,
    )
    test_lda = pd.DataFrame(
        test_lda,
        columns=[f"lda_{i}" for i in range(target.unique().shape[0] - 1)],
        index=test.index,
    )
    new_train = pd.concat([train, train_lda], axis=1)
    new_test = pd.concat([test, test_lda], axis=1)
    return new_train, new_test

# %% [markdown]
# Создадим данные для обучения

# %%
def weighted_roc_auc(y_true, y_pred):
    global weights_dict
    unnorm_weights = np.array([weights_dict[label] for label in labels])
    weights = unnorm_weights / unnorm_weights.sum()
    classes_roc_auc = roc_auc_score(
        y_true, y_pred, labels=labels, multi_class="ovr", average=None
    )
    return sum(weights * classes_roc_auc), dict(zip(labels, classes_roc_auc))


train_df_3m_1he = pd.get_dummies(
    extract_optuna_features(train_df_3m),
    columns=list(set(cat_cols_3m).intersection(best_features)),
).replace(-999, 0)
test_df_3m_1he = pd.get_dummies(
    extract_optuna_features(test_df_3m),
    columns=list(set(cat_cols_3m).intersection(best_features)),
).replace(-999, 0)

X = train_df_3m.drop(["end_cluster"], axis=1)
X_1he = train_df_3m_1he.drop(["end_cluster"], axis=1)
X_lda, X_test_lda = add_lda(
    X_1he, train_df_3m_1he["end_cluster"], test_df_3m_1he, X, test_df_3m
)
y = train_df_3m["end_cluster"]

(
    x_train,
    x_val,
    x_train_1he,
    x_val_1he,
    x_train_lda,
    x_val_lda,
    y_train,
    y_val,
) = train_test_split(X, X_1he, X_lda, y, test_size=0.2, random_state=42)

x_train.shape, x_train_1he.shape, X_lda.shape, x_train_lda.shape
# Out:
# ((167626, 260), (167626, 391), (209533, 276), (167626, 276))

# %% [markdown]
# Запустим стекинг из катбустов на 5и фолдах, для того чтобы найти выбросы в тренировочных данных

# %%
class StackCatBoost:
    def __init__(
        self, n_folds, n_estimators, learning_rate, max_depth, cat_features
    ):
        self.n_folds = n_folds
        self.n_estimators = n_estimators
        self.learning_rate = learning_rate
        self.max_depth = max_depth
        self.cat_features = cat_features
        self.models = []
        for i in range(n_folds):
            self.models.append(
                CatBoostClassifier(
                    n_estimators=n_estimators,
                    learning_rate=learning_rate,
                    max_depth=max_depth,
                    cat_features=cat_features,
                    verbose=0,
                    random_seed=42,
                    task_type="GPU",
                    devices="0:1",
                )
            )

    def fit(self, X, y):
        skf = StratifiedKFold(
            n_splits=self.n_folds, shuffle=True, random_state=42
        )
        self.stacking_train_preds = np.zeros((len(X), 17))
        for fold, (train_index, val_index) in enumerate(skf.split(X, y)):
            print(f"Training on fold {fold+1}/{self.n_folds}")
            X_train, X_val = X.iloc[train_index], X.iloc[val_index]
            y_train, y_val = y.iloc[train_index], y.iloc[val_index]
            self.models[fold].fit(X_train, y_train)
            val_preds = self.models[fold].predict_proba(X_val)
            self.stacking_train_preds[val_index] = val_preds
        self.overall_score = weighted_roc_auc(y, self.stacking_train_preds)
        print(f"Overall validation score: {self.overall_score}")

    def predict_proba(self, X):
        preds = np.zeros((len(X), 17))
        for model in self.models:
            preds += model.predict_proba(X)
        return preds / self.n_folds


stack = StackCatBoost(5, 3000, 0.05, 3, cat_cols_3m)
stack.fit(X_lda, y)
# Out:
# Training on fold 1/5
# Training on fold 2/5
# Training on fold 3/5
# Training on fold 4/5
# Training on fold 5/5
# Overall validation score: (0.912539298426308, {'{other}': 0.9141819795373111, '{}': 0.9193086787473701, '{α, β}': 0.8953225074292648, '{α, γ}': 0.9204913320004809, '{α, δ}': 0.9060672556613131, '{α, ε, η}': 0.9509625686473151, '{α, ε, θ}': 0.9104360247065114, '{α, ε, ψ}': 0.9385037547790268, '{α, ε}': 0.8823184655151521, '{α, η}': 0.9674370101248616, '{α, θ}': 0.8839686814709112, '{α, λ}': 0.9215138583777598, '{α, μ}': 0.8801453478772847, '{α, π}': 0.8771801382154175, '{α, ψ}': 0.9389086993363798, '{α}': 0.869776365708007, '{λ}': 0.9026180558721741})

# %% [markdown]
# Удалим выбросы

# %%
from sklearn.preprocessing import LabelEncoder
thr = 0.5
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
misses = stack.stacking_train_preds.argmax(axis=1) != label_encoder.transform(y)
clear_X_lda = X_lda.drop(
    X_lda[stack.stacking_train_preds.max(axis=1) < thr].index, axis=0
)
clear_y = y.drop(y[stack.stacking_train_preds.max(axis=1) < thr].index, axis=0)
clear_X_lda.shape
# Out:
# (188612, 276)

# %% [markdown]
# Обучим итоговую модель

# %%
model = CatBoostClassifier(
    cat_features=cat_cols_3m,
    iterations=3000,
    depth=4,  # 4 better 3 auto better
    learning_rate=0.05,
    task_type="GPU",
    devices="0:1",
    # loss_function="MultiClassOneVsAll",
    random_seed=42,
    # eval_metric="AUC",
)

model.fit(clear_X_lda, clear_y)
# Out:
# 0:	learn: 2.3972303	total: 24.2ms	remaining: 1m 12s
# 1:	learn: 2.1588612	total: 50ms	remaining: 1m 14s
# 2:	learn: 1.9912567	total: 72.4ms	remaining: 1m 12s
# 3:	learn: 1.8608643	total: 97ms	remaining: 1m 12s
# 4:	learn: 1.7559524	total: 122ms	remaining: 1m 12s
# 5:	learn: 1.6678832	total: 147ms	remaining: 1m 13s
# 6:	learn: 1.5919152	total: 172ms	remaining: 1m 13s
# 7:	learn: 1.5273357	total: 198ms	remaining: 1m 14s
# 8:	learn: 1.4707392	total: 223ms	remaining: 1m 14s
# 9:	learn: 1.4197667	total: 248ms	remaining: 1m 14s
# 10:	learn: 1.3750910	total: 272ms	remaining: 1m 14s
# 11:	learn: 1.3351406	total: 300ms	remaining: 1m 14s
# 12:	learn: 1.2981989	total: 324ms	remaining: 1m 14s
# 13:	learn: 1.2656926	total: 349ms	remaining: 1m 14s
# 14:	learn: 1.2352934	total: 373ms	remaining: 1m 14s
# 15:	learn: 1.2077077	total: 397ms	remaining: 1m 14s
# 16:	learn: 1.1823706	total: 420ms	remaining: 1m 13s
# 17:	learn: 1.1592332	total: 443ms	remaining: 1m 13s
# 18:	learn: 1.1381053	total: 466ms	remaining: 1m 13s
# 19:	learn: 1.1182612	total: 489ms	remaining: 1m 12s
# 20:	learn: 1.0991380	total: 514ms	remaining: 1m 12s
# 21:	learn: 1.0815161	total: 537ms	remaining: 1m 12s
# 22:	learn: 1.0652407	total: 562ms	remaining: 1m 12s
# 23:	learn: 1.0502250	total: 585ms	remaining: 1m 12s
# 24:	learn: 1.0363108	total: 610ms	remaining: 1m 12s
# 25:	learn: 1.0233043	total: 634ms	remaining: 1m 12s
# 26:	learn: 1.0113068	total: 659ms	remaining: 1m 12s
# 27:	learn: 0.9993951	total: 683ms	remaining: 1m 12s
# 28:	learn: 0.9883204	total: 706ms	remaining: 1m 12s
# 29:	learn: 0.9785278	total: 731ms	remaining: 1m 12s
# 30:	learn: 0.9693783	total: 755ms	remaining: 1m 12s
# 31:	learn: 0.9604555	total: 780ms	remaining: 1m 12s
# 32:	learn: 0.9522252	total: 803ms	remaining: 1m 12s
# 33:	learn: 0.9444129	total: 828ms	remaining: 1m 12s
# 34:	learn: 0.9372271	total: 851ms	remaining: 1m 12s
# 35:	learn: 0.9304114	total: 876ms	remaining: 1m 12s
# 36:	learn: 0.9237299	total: 899ms	remaining: 1m 12s
# 37:	learn: 0.9174244	total: 924ms	remaining: 1m 12s
# 38:	learn: 0.9117113	total: 948ms	remaining: 1m 11s
# 39:	learn: 0.9061808	total: 972ms	remaining: 1m 11s
# 40:	learn: 0.9011819	total: 996ms	remaining: 1m 11s
# 41:	learn: 0.8962462	total: 1.02s	remaining: 1m 11s
# 42:	learn: 0.8914315	total: 1.04s	remaining: 1m 11s
# 43:	learn: 0.8869447	total: 1.07s	remaining: 1m 11s
# 44:	learn: 0.8827466	total: 1.09s	remaining: 1m 11s
# 45:	learn: 0.8789314	total: 1.11s	remaining: 1m 11s
# 46:	learn: 0.8752494	total: 1.14s	remaining: 1m 11s
# 47:	learn: 0.8717474	total: 1.16s	remaining: 1m 11s
# 48:	learn: 0.8684977	total: 1.18s	remaining: 1m 11s
# 49:	learn: 0.8654081	total: 1.21s	remaining: 1m 11s
# 50:	learn: 0.8619488	total: 1.23s	remaining: 1m 10s
# 51:	learn: 0.8582277	total: 1.25s	remaining: 1m 10s
# 52:	learn: 0.8552849	total: 1.27s	remaining: 1m 10s
# 53:	learn: 0.8527992	total: 1.3s	remaining: 1m 10s
# 54:	learn: 0.8501427	total: 1.32s	remaining: 1m 10s
# 55:	learn: 0.8474960	total: 1.35s	remaining: 1m 10s
# 56:	learn: 0.8448301	total: 1.37s	remaining: 1m 10s
# 57:	learn: 0.8426612	total: 1.39s	remaining: 1m 10s
# 58:	learn: 0.8407561	total: 1.41s	remaining: 1m 10s
# 59:	learn: 0.8388446	total: 1.44s	remaining: 1m 10s
# 60:	learn: 0.8370221	total: 1.46s	remaining: 1m 10s
# 61:	learn: 0.8348767	total: 1.48s	remaining: 1m 10s
# 62:	learn: 0.8333148	total: 1.5s	remaining: 1m 9s
# 63:	learn: 0.8316657	total: 1.52s	remaining: 1m 9s
# 64:	learn: 0.8297239	total: 1.55s	remaining: 1m 9s
# 65:	learn: 0.8282937	total: 1.57s	remaining: 1m 9s
# 66:	learn: 0.8265319	total: 1.59s	remaining: 1m 9s
# 67:	learn: 0.8249086	total: 1.62s	remaining: 1m 9s
# 68:	learn: 0.8236558	total: 1.64s	remaining: 1m 9s
# 69:	learn: 0.8225939	total: 1.66s	remaining: 1m 9s
# 70:	learn: 0.8211939	total: 1.69s	remaining: 1m 9s
# 71:	learn: 0.8198795	total: 1.71s	remaining: 1m 9s
# 72:	learn: 0.8188736	total: 1.73s	remaining: 1m 9s
# 73:	learn: 0.8173497	total: 1.75s	remaining: 1m 9s
# 74:	learn: 0.8162954	total: 1.77s	remaining: 1m 9s
# 75:	learn: 0.8149397	total: 1.8s	remaining: 1m 9s
# 76:	learn: 0.8139319	total: 1.83s	remaining: 1m 9s
# 77:	learn: 0.8127233	total: 1.85s	remaining: 1m 9s
# 78:	learn: 0.8115343	total: 1.87s	remaining: 1m 9s
# 79:	learn: 0.8106141	total: 1.9s	remaining: 1m 9s
# 80:	learn: 0.8094552	total: 1.92s	remaining: 1m 9s
# 81:	learn: 0.8084440	total: 1.94s	remaining: 1m 9s
# 82:	learn: 0.8073381	total: 1.97s	remaining: 1m 9s
# 83:	learn: 0.8066165	total: 1.99s	remaining: 1m 9s
# 84:	learn: 0.8057214	total: 2.01s	remaining: 1m 8s
# 85:	learn: 0.8046904	total: 2.03s	remaining: 1m 8s
# 86:	learn: 0.8039674	total: 2.06s	remaining: 1m 8s
# 87:	learn: 0.8030355	total: 2.08s	remaining: 1m 8s
# 88:	learn: 0.8022196	total: 2.1s	remaining: 1m 8s
# 89:	learn: 0.8013298	total: 2.12s	remaining: 1m 8s
# 90:	learn: 0.8006463	total: 2.15s	remaining: 1m 8s
# 91:	learn: 0.7999666	total: 2.17s	remaining: 1m 8s
# 92:	learn: 0.7994169	total: 2.19s	remaining: 1m 8s
# 93:	learn: 0.7988603	total: 2.22s	remaining: 1m 8s
# 94:	learn: 0.7982420	total: 2.24s	remaining: 1m 8s
# 95:	learn: 0.7976226	total: 2.26s	remaining: 1m 8s
# 96:	learn: 0.7971770	total: 2.28s	remaining: 1m 8s
# 97:	learn: 0.7965479	total: 2.31s	remaining: 1m 8s
# 98:	learn: 0.7960048	total: 2.33s	remaining: 1m 8s
# 99:	learn: 0.7954177	total: 2.35s	remaining: 1m 8s
# 100:	learn: 0.7949059	total: 2.38s	remaining: 1m 8s
# 101:	learn: 0.7940952	total: 2.4s	remaining: 1m 8s
# 102:	learn: 0.7934846	total: 2.42s	remaining: 1m 8s
# 103:	learn: 0.7928066	total: 2.44s	remaining: 1m 8s
# 104:	learn: 0.7922443	total: 2.46s	remaining: 1m 7s
# 105:	learn: 0.7917712	total: 2.49s	remaining: 1m 7s
# 106:	learn: 0.7912409	total: 2.51s	remaining: 1m 7s
# 107:	learn: 0.7907822	total: 2.54s	remaining: 1m 7s
# 108:	learn: 0.7903568	total: 2.56s	remaining: 1m 7s
# 109:	learn: 0.7899851	total: 2.58s	remaining: 1m 7s
# 110:	learn: 0.7895808	total: 2.6s	remaining: 1m 7s
# 111:	learn: 0.7890934	total: 2.63s	remaining: 1m 7s
# 112:	learn: 0.7884887	total: 2.65s	remaining: 1m 7s
# 113:	learn: 0.7881064	total: 2.67s	remaining: 1m 7s
# 114:	learn: 0.7877275	total: 2.69s	remaining: 1m 7s
# 115:	learn: 0.7872878	total: 2.72s	remaining: 1m 7s
# 116:	learn: 0.7868407	total: 2.74s	remaining: 1m 7s
# 117:	learn: 0.7864020	total: 2.76s	remaining: 1m 7s
# 118:	learn: 0.7860050	total: 2.79s	remaining: 1m 7s
# 119:	learn: 0.7856835	total: 2.81s	remaining: 1m 7s
# 120:	learn: 0.7852543	total: 2.83s	remaining: 1m 7s
# 121:	learn: 0.7849391	total: 2.86s	remaining: 1m 7s
# 122:	learn: 0.7843205	total: 2.88s	remaining: 1m 7s
# 123:	learn: 0.7841004	total: 2.9s	remaining: 1m 7s
# 124:	learn: 0.7836862	total: 2.93s	remaining: 1m 7s
# 125:	learn: 0.7833348	total: 2.95s	remaining: 1m 7s
# 126:	learn: 0.7829582	total: 2.97s	remaining: 1m 7s
# 127:	learn: 0.7826765	total: 2.99s	remaining: 1m 7s
# 128:	learn: 0.7823823	total: 3.02s	remaining: 1m 7s
# 129:	learn: 0.7819674	total: 3.04s	remaining: 1m 7s
# 130:	learn: 0.7816822	total: 3.06s	remaining: 1m 7s
# 131:	learn: 0.7814163	total: 3.08s	remaining: 1m 6s
# 132:	learn: 0.7809660	total: 3.11s	remaining: 1m 6s
# 133:	learn: 0.7806724	total: 3.13s	remaining: 1m 6s
# 134:	learn: 0.7804188	total: 3.15s	remaining: 1m 6s
# 135:	learn: 0.7800743	total: 3.17s	remaining: 1m 6s
# 136:	learn: 0.7796557	total: 3.2s	remaining: 1m 6s
# 137:	learn: 0.7794230	total: 3.22s	remaining: 1m 6s
# 138:	learn: 0.7789270	total: 3.24s	remaining: 1m 6s
# 139:	learn: 0.7786844	total: 3.27s	remaining: 1m 6s
# 140:	learn: 0.7782814	total: 3.29s	remaining: 1m 6s
# 141:	learn: 0.7780358	total: 3.31s	remaining: 1m 6s
# 142:	learn: 0.7777627	total: 3.34s	remaining: 1m 6s
# 143:	learn: 0.7774125	total: 3.36s	remaining: 1m 6s
# 144:	learn: 0.7772079	total: 3.38s	remaining: 1m 6s
# 145:	learn: 0.7769738	total: 3.4s	remaining: 1m 6s
# 146:	learn: 0.7766995	total: 3.42s	remaining: 1m 6s
# 147:	learn: 0.7764802	total: 3.45s	remaining: 1m 6s
# 148:	learn: 0.7761960	total: 3.47s	remaining: 1m 6s
# 149:	learn: 0.7758669	total: 3.49s	remaining: 1m 6s
# 150:	learn: 0.7754825	total: 3.52s	remaining: 1m 6s
# 151:	learn: 0.7753053	total: 3.54s	remaining: 1m 6s
# 152:	learn: 0.7750636	total: 3.56s	remaining: 1m 6s
# 153:	learn: 0.7748783	total: 3.58s	remaining: 1m 6s
# 154:	learn: 0.7745970	total: 3.6s	remaining: 1m 6s
# 155:	learn: 0.7742973	total: 3.63s	remaining: 1m 6s
# 156:	learn: 0.7740683	total: 3.65s	remaining: 1m 6s
# 157:	learn: 0.7737597	total: 3.67s	remaining: 1m 6s
# 158:	learn: 0.7735081	total: 3.69s	remaining: 1m 6s
# 159:	learn: 0.7732631	total: 3.72s	remaining: 1m 5s
# 160:	learn: 0.7729933	total: 3.74s	remaining: 1m 5s
# 161:	learn: 0.7727199	total: 3.76s	remaining: 1m 5s
# 162:	learn: 0.7724377	total: 3.78s	remaining: 1m 5s
# 163:	learn: 0.7722160	total: 3.81s	remaining: 1m 5s
# 164:	learn: 0.7719599	total: 3.83s	remaining: 1m 5s
# 165:	learn: 0.7717291	total: 3.85s	remaining: 1m 5s
# 166:	learn: 0.7714912	total: 3.87s	remaining: 1m 5s
# 167:	learn: 0.7712398	total: 3.9s	remaining: 1m 5s
# 168:	learn: 0.7711125	total: 3.92s	remaining: 1m 5s
# 169:	learn: 0.7708122	total: 3.94s	remaining: 1m 5s
# 170:	learn: 0.7706261	total: 3.97s	remaining: 1m 5s
# 171:	learn: 0.7702897	total: 3.99s	remaining: 1m 5s
# 172:	learn: 0.7700265	total: 4.01s	remaining: 1m 5s
# 173:	learn: 0.7698247	total: 4.04s	remaining: 1m 5s
# 174:	learn: 0.7697014	total: 4.06s	remaining: 1m 5s
# 175:	learn: 0.7694964	total: 4.08s	remaining: 1m 5s
# 176:	learn: 0.7692580	total: 4.1s	remaining: 1m 5s
# 177:	learn: 0.7691367	total: 4.13s	remaining: 1m 5s
# 178:	learn: 0.7689621	total: 4.15s	remaining: 1m 5s
# 179:	learn: 0.7686997	total: 4.17s	remaining: 1m 5s
# 180:	learn: 0.7685298	total: 4.19s	remaining: 1m 5s
# 181:	learn: 0.7683682	total: 4.21s	remaining: 1m 5s
# 182:	learn: 0.7681820	total: 4.24s	remaining: 1m 5s
# 183:	learn: 0.7680109	total: 4.26s	remaining: 1m 5s
# 184:	learn: 0.7677707	total: 4.28s	remaining: 1m 5s
# 185:	learn: 0.7675844	total: 4.31s	remaining: 1m 5s
# 186:	learn: 0.7673958	total: 4.33s	remaining: 1m 5s
# 187:	learn: 0.7672595	total: 4.35s	remaining: 1m 5s
# 188:	learn: 0.7671308	total: 4.37s	remaining: 1m 5s
# 189:	learn: 0.7669675	total: 4.39s	remaining: 1m 5s
# 190:	learn: 0.7667336	total: 4.42s	remaining: 1m 4s
# 191:	learn: 0.7665136	total: 4.44s	remaining: 1m 4s
# 192:	learn: 0.7663280	total: 4.46s	remaining: 1m 4s
# 193:	learn: 0.7661549	total: 4.49s	remaining: 1m 4s
# 194:	learn: 0.7659579	total: 4.51s	remaining: 1m 4s
# 195:	learn: 0.7657978	total: 4.53s	remaining: 1m 4s
# 196:	learn: 0.7656533	total: 4.55s	remaining: 1m 4s
# 197:	learn: 0.7654895	total: 4.57s	remaining: 1m 4s
# 198:	learn: 0.7652085	total: 4.6s	remaining: 1m 4s
# 199:	learn: 0.7650504	total: 4.62s	remaining: 1m 4s
# 200:	learn: 0.7648913	total: 4.64s	remaining: 1m 4s
# 201:	learn: 0.7646447	total: 4.67s	remaining: 1m 4s
# 202:	learn: 0.7644192	total: 4.69s	remaining: 1m 4s
# 203:	learn: 0.7642523	total: 4.71s	remaining: 1m 4s
# 204:	learn: 0.7640867	total: 4.73s	remaining: 1m 4s
# 205:	learn: 0.7639151	total: 4.76s	remaining: 1m 4s
# 206:	learn: 0.7637742	total: 4.78s	remaining: 1m 4s
# 207:	learn: 0.7636475	total: 4.8s	remaining: 1m 4s
# 208:	learn: 0.7635364	total: 4.82s	remaining: 1m 4s
# 209:	learn: 0.7633864	total: 4.84s	remaining: 1m 4s
# 210:	learn: 0.7632001	total: 4.87s	remaining: 1m 4s
# 211:	learn: 0.7630055	total: 4.89s	remaining: 1m 4s
# 212:	learn: 0.7628511	total: 4.91s	remaining: 1m 4s
# 213:	learn: 0.7626912	total: 4.94s	remaining: 1m 4s
# 214:	learn: 0.7625657	total: 4.96s	remaining: 1m 4s
# 215:	learn: 0.7623704	total: 4.98s	remaining: 1m 4s
# 216:	learn: 0.7622482	total: 5s	remaining: 1m 4s
# 217:	learn: 0.7620742	total: 5.02s	remaining: 1m 4s
# 218:	learn: 0.7619297	total: 5.05s	remaining: 1m 4s
# 219:	learn: 0.7618250	total: 5.07s	remaining: 1m 4s
# 220:	learn: 0.7616691	total: 5.09s	remaining: 1m 4s
# 221:	learn: 0.7615424	total: 5.11s	remaining: 1m 4s
# 222:	learn: 0.7613645	total: 5.14s	remaining: 1m 3s
# 223:	learn: 0.7611770	total: 5.16s	remaining: 1m 3s
# 224:	learn: 0.7610688	total: 5.18s	remaining: 1m 3s
# 225:	learn: 0.7609598	total: 5.2s	remaining: 1m 3s
# 226:	learn: 0.7608241	total: 5.22s	remaining: 1m 3s
# 227:	learn: 0.7606219	total: 5.25s	remaining: 1m 3s
# 228:	learn: 0.7604860	total: 5.27s	remaining: 1m 3s
# 229:	learn: 0.7603486	total: 5.29s	remaining: 1m 3s
# 230:	learn: 0.7602805	total: 5.32s	remaining: 1m 3s
# 231:	learn: 0.7600680	total: 5.34s	remaining: 1m 3s
# 232:	learn: 0.7599441	total: 5.36s	remaining: 1m 3s
# 233:	learn: 0.7598039	total: 5.38s	remaining: 1m 3s
# 234:	learn: 0.7595546	total: 5.4s	remaining: 1m 3s
# 235:	learn: 0.7593831	total: 5.43s	remaining: 1m 3s
# 236:	learn: 0.7592850	total: 5.45s	remaining: 1m 3s
# 237:	learn: 0.7591609	total: 5.47s	remaining: 1m 3s
# 238:	learn: 0.7590039	total: 5.5s	remaining: 1m 3s
# 239:	learn: 0.7588784	total: 5.52s	remaining: 1m 3s
# 240:	learn: 0.7587645	total: 5.54s	remaining: 1m 3s
# 241:	learn: 0.7586308	total: 5.56s	remaining: 1m 3s
# 242:	learn: 0.7585361	total: 5.58s	remaining: 1m 3s
# 243:	learn: 0.7583663	total: 5.61s	remaining: 1m 3s
# 244:	learn: 0.7582545	total: 5.63s	remaining: 1m 3s
# 245:	learn: 0.7580409	total: 5.65s	remaining: 1m 3s
# 246:	learn: 0.7579158	total: 5.67s	remaining: 1m 3s
# 247:	learn: 0.7577505	total: 5.69s	remaining: 1m 3s
# 248:	learn: 0.7576460	total: 5.72s	remaining: 1m 3s
# 249:	learn: 0.7574825	total: 5.74s	remaining: 1m 3s
# 250:	learn: 0.7573061	total: 5.76s	remaining: 1m 3s
# 251:	learn: 0.7572111	total: 5.79s	remaining: 1m 3s
# 252:	learn: 0.7570350	total: 5.81s	remaining: 1m 3s
# 253:	learn: 0.7568785	total: 5.83s	remaining: 1m 3s
# 254:	learn: 0.7567361	total: 5.85s	remaining: 1m 3s
# 255:	learn: 0.7565973	total: 5.88s	remaining: 1m 2s
# 256:	learn: 0.7564917	total: 5.9s	remaining: 1m 2s
# 257:	learn: 0.7563967	total: 5.92s	remaining: 1m 2s
# 258:	learn: 0.7562204	total: 5.95s	remaining: 1m 2s
# 259:	learn: 0.7560441	total: 5.97s	remaining: 1m 2s
# 260:	learn: 0.7559262	total: 5.99s	remaining: 1m 2s
# 261:	learn: 0.7557810	total: 6.01s	remaining: 1m 2s
# 262:	learn: 0.7556585	total: 6.04s	remaining: 1m 2s
# 263:	learn: 0.7555771	total: 6.06s	remaining: 1m 2s
# 264:	learn: 0.7554648	total: 6.08s	remaining: 1m 2s
# 265:	learn: 0.7553788	total: 6.1s	remaining: 1m 2s
# 266:	learn: 0.7552861	total: 6.12s	remaining: 1m 2s
# 267:	learn: 0.7551921	total: 6.15s	remaining: 1m 2s
# 268:	learn: 0.7550386	total: 6.17s	remaining: 1m 2s
# 269:	learn: 0.7549105	total: 6.19s	remaining: 1m 2s
# 270:	learn: 0.7547953	total: 6.21s	remaining: 1m 2s
# 271:	learn: 0.7547099	total: 6.24s	remaining: 1m 2s
# 272:	learn: 0.7546057	total: 6.26s	remaining: 1m 2s
# 273:	learn: 0.7545020	total: 6.28s	remaining: 1m 2s
# 274:	learn: 0.7543764	total: 6.3s	remaining: 1m 2s
# 275:	learn: 0.7543042	total: 6.32s	remaining: 1m 2s
# 276:	learn: 0.7541445	total: 6.35s	remaining: 1m 2s
# 277:	learn: 0.7540586	total: 6.37s	remaining: 1m 2s
# 278:	learn: 0.7539613	total: 6.39s	remaining: 1m 2s
# 279:	learn: 0.7538408	total: 6.41s	remaining: 1m 2s
# 280:	learn: 0.7536919	total: 6.44s	remaining: 1m 2s
# 281:	learn: 0.7535590	total: 6.46s	remaining: 1m 2s
# 282:	learn: 0.7534837	total: 6.48s	remaining: 1m 2s
# 283:	learn: 0.7533532	total: 6.5s	remaining: 1m 2s
# 284:	learn: 0.7532667	total: 6.52s	remaining: 1m 2s
# 285:	learn: 0.7531471	total: 6.55s	remaining: 1m 2s
# 286:	learn: 0.7529712	total: 6.57s	remaining: 1m 2s
# 287:	learn: 0.7529030	total: 6.59s	remaining: 1m 2s
# 288:	learn: 0.7528410	total: 6.61s	remaining: 1m 2s
# 289:	learn: 0.7527195	total: 6.63s	remaining: 1m 2s
# 290:	learn: 0.7526360	total: 6.66s	remaining: 1m 1s
# 291:	learn: 0.7524633	total: 6.68s	remaining: 1m 1s
# 292:	learn: 0.7523439	total: 6.7s	remaining: 1m 1s
# 293:	learn: 0.7522405	total: 6.72s	remaining: 1m 1s
# 294:	learn: 0.7521720	total: 6.75s	remaining: 1m 1s
# 295:	learn: 0.7520515	total: 6.77s	remaining: 1m 1s
# 296:	learn: 0.7519319	total: 6.79s	remaining: 1m 1s
# 297:	learn: 0.7518395	total: 6.81s	remaining: 1m 1s
# 298:	learn: 0.7517547	total: 6.83s	remaining: 1m 1s
# 299:	learn: 0.7516129	total: 6.86s	remaining: 1m 1s
# 300:	learn: 0.7515176	total: 6.88s	remaining: 1m 1s
# 301:	learn: 0.7514139	total: 6.9s	remaining: 1m 1s
# 302:	learn: 0.7513361	total: 6.92s	remaining: 1m 1s
# 303:	learn: 0.7511996	total: 6.95s	remaining: 1m 1s
# 304:	learn: 0.7511272	total: 6.97s	remaining: 1m 1s
# 305:	learn: 0.7510364	total: 6.99s	remaining: 1m 1s
# 306:	learn: 0.7509313	total: 7.01s	remaining: 1m 1s
# 307:	learn: 0.7508567	total: 7.04s	remaining: 1m 1s
# 308:	learn: 0.7506945	total: 7.06s	remaining: 1m 1s
# 309:	learn: 0.7505502	total: 7.08s	remaining: 1m 1s
# 310:	learn: 0.7504744	total: 7.11s	remaining: 1m 1s
# 311:	learn: 0.7503957	total: 7.13s	remaining: 1m 1s
# 312:	learn: 0.7502494	total: 7.15s	remaining: 1m 1s
# 313:	learn: 0.7501207	total: 7.17s	remaining: 1m 1s
# 314:	learn: 0.7500737	total: 7.2s	remaining: 1m 1s
# 315:	learn: 0.7499858	total: 7.22s	remaining: 1m 1s
# 316:	learn: 0.7498907	total: 7.24s	remaining: 1m 1s
# 317:	learn: 0.7497683	total: 7.26s	remaining: 1m 1s
# 318:	learn: 0.7496793	total: 7.28s	remaining: 1m 1s
# 319:	learn: 0.7495981	total: 7.31s	remaining: 1m 1s
# 320:	learn: 0.7494719	total: 7.33s	remaining: 1m 1s
# 321:	learn: 0.7493623	total: 7.35s	remaining: 1m 1s
# 322:	learn: 0.7492729	total: 7.38s	remaining: 1m 1s
# 323:	learn: 0.7491472	total: 7.4s	remaining: 1m 1s
# 324:	learn: 0.7490460	total: 7.42s	remaining: 1m 1s
# 325:	learn: 0.7489434	total: 7.44s	remaining: 1m 1s
# 326:	learn: 0.7488683	total: 7.46s	remaining: 1m 1s
# 327:	learn: 0.7487932	total: 7.49s	remaining: 1m
# 328:	learn: 0.7486906	total: 7.51s	remaining: 1m
# 329:	learn: 0.7486222	total: 7.53s	remaining: 1m
# 330:	learn: 0.7485245	total: 7.55s	remaining: 1m
# 331:	learn: 0.7484562	total: 7.57s	remaining: 1m
# 332:	learn: 0.7483842	total: 7.6s	remaining: 1m
# 333:	learn: 0.7483091	total: 7.62s	remaining: 1m
# 334:	learn: 0.7482104	total: 7.64s	remaining: 1m
# 335:	learn: 0.7481045	total: 7.67s	remaining: 1m
# 336:	learn: 0.7480285	total: 7.69s	remaining: 1m
# 337:	learn: 0.7479679	total: 7.71s	remaining: 1m
# 338:	learn: 0.7479101	total: 7.73s	remaining: 1m
# 339:	learn: 0.7478216	total: 7.75s	remaining: 1m
# 340:	learn: 0.7477528	total: 7.78s	remaining: 1m
# 341:	learn: 0.7476354	total: 7.8s	remaining: 1m
# 342:	learn: 0.7475721	total: 7.82s	remaining: 1m
# 343:	learn: 0.7474873	total: 7.84s	remaining: 1m
# 344:	learn: 0.7474032	total: 7.87s	remaining: 1m
# 345:	learn: 0.7473392	total: 7.89s	remaining: 1m
# 346:	learn: 0.7472648	total: 7.91s	remaining: 1m
# 347:	learn: 0.7472105	total: 7.93s	remaining: 1m
# 348:	learn: 0.7471313	total: 7.96s	remaining: 1m
# 349:	learn: 0.7470497	total: 7.98s	remaining: 1m
# 350:	learn: 0.7469736	total: 8s	remaining: 1m
# 351:	learn: 0.7468698	total: 8.02s	remaining: 1m
# 352:	learn: 0.7468029	total: 8.04s	remaining: 1m
# 353:	learn: 0.7467284	total: 8.07s	remaining: 1m
# 354:	learn: 0.7466473	total: 8.09s	remaining: 1m
# 355:	learn: 0.7465124	total: 8.11s	remaining: 1m
# 356:	learn: 0.7464090	total: 8.13s	remaining: 1m
# 357:	learn: 0.7462858	total: 8.16s	remaining: 1m
# 358:	learn: 0.7461927	total: 8.18s	remaining: 1m
# 359:	learn: 0.7461005	total: 8.2s	remaining: 1m
# 360:	learn: 0.7460718	total: 8.22s	remaining: 1m
# 361:	learn: 0.7460159	total: 8.24s	remaining: 1m
# 362:	learn: 0.7459296	total: 8.27s	remaining: 1m
# 363:	learn: 0.7458588	total: 8.29s	remaining: 1m
# 364:	learn: 0.7458023	total: 8.31s	remaining: 60s
# 365:	learn: 0.7457015	total: 8.33s	remaining: 60s
# 366:	learn: 0.7456476	total: 8.35s	remaining: 59.9s
# 367:	learn: 0.7455352	total: 8.38s	remaining: 59.9s
# 368:	learn: 0.7454442	total: 8.4s	remaining: 59.9s
# 369:	learn: 0.7453681	total: 8.42s	remaining: 59.9s
# 370:	learn: 0.7453097	total: 8.44s	remaining: 59.8s
# 371:	learn: 0.7452546	total: 8.46s	remaining: 59.8s
# 372:	learn: 0.7452131	total: 8.48s	remaining: 59.8s
# 373:	learn: 0.7451397	total: 8.51s	remaining: 59.7s
# 374:	learn: 0.7450744	total: 8.53s	remaining: 59.7s
# 375:	learn: 0.7450054	total: 8.55s	remaining: 59.7s
# 376:	learn: 0.7449172	total: 8.57s	remaining: 59.7s
# 377:	learn: 0.7448732	total: 8.59s	remaining: 59.6s
# 378:	learn: 0.7448054	total: 8.62s	remaining: 59.6s
# 379:	learn: 0.7447395	total: 8.64s	remaining: 59.6s
# 380:	learn: 0.7446665	total: 8.66s	remaining: 59.5s
# 381:	learn: 0.7445613	total: 8.69s	remaining: 59.5s
# 382:	learn: 0.7445298	total: 8.71s	remaining: 59.5s
# 383:	learn: 0.7444739	total: 8.73s	remaining: 59.5s
# 384:	learn: 0.7443942	total: 8.75s	remaining: 59.4s
# 385:	learn: 0.7443541	total: 8.77s	remaining: 59.4s
# 386:	learn: 0.7442702	total: 8.79s	remaining: 59.4s
# 387:	learn: 0.7442195	total: 8.81s	remaining: 59.3s
# 388:	learn: 0.7441866	total: 8.84s	remaining: 59.3s
# 389:	learn: 0.7440736	total: 8.86s	remaining: 59.3s
# 390:	learn: 0.7440360	total: 8.88s	remaining: 59.3s
# 391:	learn: 0.7439938	total: 8.9s	remaining: 59.2s
# 392:	learn: 0.7439266	total: 8.92s	remaining: 59.2s
# 393:	learn: 0.7438354	total: 8.95s	remaining: 59.2s
# 394:	learn: 0.7437378	total: 8.97s	remaining: 59.2s
# 395:	learn: 0.7436604	total: 8.99s	remaining: 59.2s
# 396:	learn: 0.7436053	total: 9.02s	remaining: 59.1s
# 397:	learn: 0.7435051	total: 9.04s	remaining: 59.1s
# 398:	learn: 0.7434296	total: 9.06s	remaining: 59.1s
# 399:	learn: 0.7433489	total: 9.08s	remaining: 59s
# 400:	learn: 0.7432210	total: 9.11s	remaining: 59s
# 401:	learn: 0.7431703	total: 9.13s	remaining: 59s
# 402:	learn: 0.7430944	total: 9.15s	remaining: 59s
# 403:	learn: 0.7430000	total: 9.17s	remaining: 58.9s
# 404:	learn: 0.7429011	total: 9.2s	remaining: 58.9s
# 405:	learn: 0.7428153	total: 9.22s	remaining: 58.9s
# 406:	learn: 0.7427458	total: 9.24s	remaining: 58.9s
# 407:	learn: 0.7426420	total: 9.26s	remaining: 58.9s
# 408:	learn: 0.7425907	total: 9.28s	remaining: 58.8s
# 409:	learn: 0.7425287	total: 9.3s	remaining: 58.8s
# 410:	learn: 0.7424641	total: 9.33s	remaining: 58.8s
# 411:	learn: 0.7424195	total: 9.35s	remaining: 58.7s
# 412:	learn: 0.7423649	total: 9.37s	remaining: 58.7s
# 413:	learn: 0.7422872	total: 9.39s	remaining: 58.7s
# 414:	learn: 0.7422343	total: 9.41s	remaining: 58.6s
# 415:	learn: 0.7421690	total: 9.44s	remaining: 58.6s
# 416:	learn: 0.7421125	total: 9.46s	remaining: 58.6s
# 417:	learn: 0.7420303	total: 9.48s	remaining: 58.6s
# 418:	learn: 0.7419934	total: 9.5s	remaining: 58.5s
# 419:	learn: 0.7419318	total: 9.53s	remaining: 58.5s
# 420:	learn: 0.7418726	total: 9.55s	remaining: 58.5s
# 421:	learn: 0.7418142	total: 9.57s	remaining: 58.5s
# 422:	learn: 0.7417513	total: 9.59s	remaining: 58.4s
# 423:	learn: 0.7416854	total: 9.61s	remaining: 58.4s
# 424:	learn: 0.7416426	total: 9.63s	remaining: 58.4s
# 425:	learn: 0.7416040	total: 9.66s	remaining: 58.4s
# 426:	learn: 0.7415192	total: 9.68s	remaining: 58.3s
# 427:	learn: 0.7414815	total: 9.7s	remaining: 58.3s
# 428:	learn: 0.7414338	total: 9.72s	remaining: 58.3s
# 429:	learn: 0.7413554	total: 9.74s	remaining: 58.2s
# 430:	learn: 0.7413147	total: 9.76s	remaining: 58.2s
# 431:	learn: 0.7412550	total: 9.79s	remaining: 58.2s
# 432:	learn: 0.7411526	total: 9.81s	remaining: 58.2s
# 433:	learn: 0.7410817	total: 9.83s	remaining: 58.1s
# 434:	learn: 0.7410329	total: 9.85s	remaining: 58.1s
# 435:	learn: 0.7409437	total: 9.88s	remaining: 58.1s
# 436:	learn: 0.7408426	total: 9.9s	remaining: 58.1s
# 437:	learn: 0.7407849	total: 9.92s	remaining: 58s
# 438:	learn: 0.7407000	total: 9.94s	remaining: 58s
# 439:	learn: 0.7406689	total: 9.96s	remaining: 58s
# 440:	learn: 0.7405637	total: 9.99s	remaining: 58s
# 441:	learn: 0.7405066	total: 10s	remaining: 57.9s
# 442:	learn: 0.7404553	total: 10s	remaining: 57.9s
# 443:	learn: 0.7403830	total: 10.1s	remaining: 57.9s
# 444:	learn: 0.7403134	total: 10.1s	remaining: 57.9s
# 445:	learn: 0.7402338	total: 10.1s	remaining: 57.8s
# 446:	learn: 0.7401828	total: 10.1s	remaining: 57.8s
# 447:	learn: 0.7401306	total: 10.1s	remaining: 57.8s
# 448:	learn: 0.7400642	total: 10.2s	remaining: 57.8s
# 449:	learn: 0.7399961	total: 10.2s	remaining: 57.8s
# 450:	learn: 0.7399297	total: 10.2s	remaining: 57.7s
# 451:	learn: 0.7398644	total: 10.2s	remaining: 57.7s
# 452:	learn: 0.7397988	total: 10.3s	remaining: 57.7s
# 453:	learn: 0.7397373	total: 10.3s	remaining: 57.6s
# 454:	learn: 0.7396444	total: 10.3s	remaining: 57.6s
# 455:	learn: 0.7395855	total: 10.3s	remaining: 57.6s
# 456:	learn: 0.7395247	total: 10.3s	remaining: 57.6s
# 457:	learn: 0.7394724	total: 10.4s	remaining: 57.5s
# 458:	learn: 0.7394171	total: 10.4s	remaining: 57.5s
# 459:	learn: 0.7393533	total: 10.4s	remaining: 57.5s
# 460:	learn: 0.7392512	total: 10.4s	remaining: 57.5s
# 461:	learn: 0.7391745	total: 10.5s	remaining: 57.4s
# 462:	learn: 0.7391265	total: 10.5s	remaining: 57.4s
# 463:	learn: 0.7390934	total: 10.5s	remaining: 57.4s
# 464:	learn: 0.7390698	total: 10.5s	remaining: 57.3s
# 465:	learn: 0.7389873	total: 10.5s	remaining: 57.3s
# 466:	learn: 0.7389373	total: 10.6s	remaining: 57.3s
# 467:	learn: 0.7388873	total: 10.6s	remaining: 57.3s
# 468:	learn: 0.7388607	total: 10.6s	remaining: 57.2s
# 469:	learn: 0.7388061	total: 10.6s	remaining: 57.2s
# 470:	learn: 0.7387599	total: 10.6s	remaining: 57.2s
# 471:	learn: 0.7387124	total: 10.7s	remaining: 57.2s
# 472:	learn: 0.7386466	total: 10.7s	remaining: 57.1s
# 473:	learn: 0.7385476	total: 10.7s	remaining: 57.1s
# 474:	learn: 0.7385048	total: 10.7s	remaining: 57.1s
# 475:	learn: 0.7384387	total: 10.8s	remaining: 57.1s
# 476:	learn: 0.7383556	total: 10.8s	remaining: 57s
# 477:	learn: 0.7382866	total: 10.8s	remaining: 57s
# 478:	learn: 0.7382025	total: 10.8s	remaining: 57s
# 479:	learn: 0.7381041	total: 10.9s	remaining: 57s
# 480:	learn: 0.7380456	total: 10.9s	remaining: 56.9s
# 481:	learn: 0.7379992	total: 10.9s	remaining: 56.9s
# 482:	learn: 0.7378979	total: 10.9s	remaining: 56.9s
# 483:	learn: 0.7378552	total: 10.9s	remaining: 56.9s
# 484:	learn: 0.7378072	total: 11s	remaining: 56.8s
# 485:	learn: 0.7377590	total: 11s	remaining: 56.8s
# 486:	learn: 0.7376860	total: 11s	remaining: 56.8s
# 487:	learn: 0.7376387	total: 11s	remaining: 56.8s
# 488:	learn: 0.7375816	total: 11.1s	remaining: 56.7s
# 489:	learn: 0.7375237	total: 11.1s	remaining: 56.7s
# 490:	learn: 0.7374515	total: 11.1s	remaining: 56.7s
# 491:	learn: 0.7374334	total: 11.1s	remaining: 56.7s
# 492:	learn: 0.7373943	total: 11.1s	remaining: 56.6s
# 493:	learn: 0.7373107	total: 11.2s	remaining: 56.6s
# 494:	learn: 0.7372659	total: 11.2s	remaining: 56.6s
# 495:	learn: 0.7372133	total: 11.2s	remaining: 56.5s
# 496:	learn: 0.7371258	total: 11.2s	remaining: 56.5s
# 497:	learn: 0.7370906	total: 11.2s	remaining: 56.5s
# 498:	learn: 0.7370200	total: 11.3s	remaining: 56.5s
# 499:	learn: 0.7369543	total: 11.3s	remaining: 56.4s
# 500:	learn: 0.7369121	total: 11.3s	remaining: 56.4s
# 501:	learn: 0.7368453	total: 11.3s	remaining: 56.4s
# 502:	learn: 0.7368162	total: 11.4s	remaining: 56.4s
# 503:	learn: 0.7367502	total: 11.4s	remaining: 56.3s
# 504:	learn: 0.7366927	total: 11.4s	remaining: 56.3s
# 505:	learn: 0.7366225	total: 11.4s	remaining: 56.3s
# 506:	learn: 0.7365805	total: 11.4s	remaining: 56.3s
# 507:	learn: 0.7365080	total: 11.5s	remaining: 56.2s
# 508:	learn: 0.7364670	total: 11.5s	remaining: 56.2s
# 509:	learn: 0.7363985	total: 11.5s	remaining: 56.2s
# 510:	learn: 0.7363669	total: 11.5s	remaining: 56.2s
# 511:	learn: 0.7363118	total: 11.5s	remaining: 56.1s
# 512:	learn: 0.7362864	total: 11.6s	remaining: 56.1s
# 513:	learn: 0.7362666	total: 11.6s	remaining: 56.1s
# 514:	learn: 0.7362210	total: 11.6s	remaining: 56s
# 515:	learn: 0.7361909	total: 11.6s	remaining: 56s
# 516:	learn: 0.7361314	total: 11.7s	remaining: 56s
# 517:	learn: 0.7360649	total: 11.7s	remaining: 56s
# 518:	learn: 0.7360339	total: 11.7s	remaining: 55.9s
# 519:	learn: 0.7360079	total: 11.7s	remaining: 55.9s
# 520:	learn: 0.7359265	total: 11.7s	remaining: 55.9s
# 521:	learn: 0.7358343	total: 11.8s	remaining: 55.9s
# 522:	learn: 0.7357672	total: 11.8s	remaining: 55.8s
# 523:	learn: 0.7356974	total: 11.8s	remaining: 55.8s
# 524:	learn: 0.7356515	total: 11.8s	remaining: 55.8s
# 525:	learn: 0.7356142	total: 11.9s	remaining: 55.8s
# 526:	learn: 0.7355680	total: 11.9s	remaining: 55.7s
# 527:	learn: 0.7355205	total: 11.9s	remaining: 55.7s
# 528:	learn: 0.7354794	total: 11.9s	remaining: 55.7s
# 529:	learn: 0.7354356	total: 11.9s	remaining: 55.6s
# 530:	learn: 0.7353593	total: 12s	remaining: 55.6s
# 531:	learn: 0.7352981	total: 12s	remaining: 55.6s
# 532:	learn: 0.7352599	total: 12s	remaining: 55.6s
# 533:	learn: 0.7351998	total: 12s	remaining: 55.6s
# 534:	learn: 0.7351453	total: 12.1s	remaining: 55.5s
# 535:	learn: 0.7350623	total: 12.1s	remaining: 55.5s
# 536:	learn: 0.7350185	total: 12.1s	remaining: 55.5s
# 537:	learn: 0.7349460	total: 12.1s	remaining: 55.5s
# 538:	learn: 0.7348702	total: 12.1s	remaining: 55.4s
# 539:	learn: 0.7348042	total: 12.2s	remaining: 55.4s
# 540:	learn: 0.7347497	total: 12.2s	remaining: 55.4s
# 541:	learn: 0.7347266	total: 12.2s	remaining: 55.4s
# 542:	learn: 0.7346321	total: 12.2s	remaining: 55.3s
# 543:	learn: 0.7346017	total: 12.3s	remaining: 55.3s
# 544:	learn: 0.7345689	total: 12.3s	remaining: 55.3s
# 545:	learn: 0.7344981	total: 12.3s	remaining: 55.3s
# 546:	learn: 0.7344694	total: 12.3s	remaining: 55.3s
# 547:	learn: 0.7344208	total: 12.3s	remaining: 55.2s
# 548:	learn: 0.7343829	total: 12.4s	remaining: 55.2s
# 549:	learn: 0.7343497	total: 12.4s	remaining: 55.2s
# 550:	learn: 0.7343144	total: 12.4s	remaining: 55.1s
# 551:	learn: 0.7342985	total: 12.4s	remaining: 55.1s
# 552:	learn: 0.7342190	total: 12.4s	remaining: 55.1s
# 553:	learn: 0.7341882	total: 12.5s	remaining: 55.1s
# 554:	learn: 0.7341466	total: 12.5s	remaining: 55s
# 555:	learn: 0.7340802	total: 12.5s	remaining: 55s
# 556:	learn: 0.7340102	total: 12.5s	remaining: 55s
# 557:	learn: 0.7339682	total: 12.6s	remaining: 55s
# 558:	learn: 0.7339203	total: 12.6s	remaining: 54.9s
# 559:	learn: 0.7338463	total: 12.6s	remaining: 54.9s
# 560:	learn: 0.7337909	total: 12.6s	remaining: 54.9s
# 561:	learn: 0.7337312	total: 12.6s	remaining: 54.8s
# 562:	learn: 0.7336836	total: 12.7s	remaining: 54.8s
# 563:	learn: 0.7336455	total: 12.7s	remaining: 54.8s
# 564:	learn: 0.7335886	total: 12.7s	remaining: 54.8s
# 565:	learn: 0.7335371	total: 12.7s	remaining: 54.8s
# 566:	learn: 0.7335004	total: 12.8s	remaining: 54.7s
# 567:	learn: 0.7334671	total: 12.8s	remaining: 54.7s
# 568:	learn: 0.7334334	total: 12.8s	remaining: 54.7s
# 569:	learn: 0.7333965	total: 12.8s	remaining: 54.6s
# 570:	learn: 0.7333374	total: 12.8s	remaining: 54.6s
# 571:	learn: 0.7333283	total: 12.9s	remaining: 54.6s
# 572:	learn: 0.7332832	total: 12.9s	remaining: 54.6s
# 573:	learn: 0.7332579	total: 12.9s	remaining: 54.6s
# 574:	learn: 0.7332289	total: 12.9s	remaining: 54.5s
# 575:	learn: 0.7332164	total: 12.9s	remaining: 54.5s
# 576:	learn: 0.7331905	total: 13s	remaining: 54.5s
# 577:	learn: 0.7331016	total: 13s	remaining: 54.4s
# 578:	learn: 0.7330588	total: 13s	remaining: 54.4s
# 579:	learn: 0.7330214	total: 13s	remaining: 54.4s
# 580:	learn: 0.7329648	total: 13.1s	remaining: 54.4s
# 581:	learn: 0.7329449	total: 13.1s	remaining: 54.4s
# 582:	learn: 0.7328973	total: 13.1s	remaining: 54.3s
# 583:	learn: 0.7328515	total: 13.1s	remaining: 54.3s
# 584:	learn: 0.7327649	total: 13.1s	remaining: 54.3s
# 585:	learn: 0.7327546	total: 13.2s	remaining: 54.3s
# 586:	learn: 0.7327143	total: 13.2s	remaining: 54.2s
# 587:	learn: 0.7326674	total: 13.2s	remaining: 54.2s
# 588:	learn: 0.7326387	total: 13.2s	remaining: 54.2s
# 589:	learn: 0.7325830	total: 13.3s	remaining: 54.2s
# 590:	learn: 0.7325628	total: 13.3s	remaining: 54.1s
# 591:	learn: 0.7325268	total: 13.3s	remaining: 54.1s
# 592:	learn: 0.7324898	total: 13.3s	remaining: 54.1s
# 593:	learn: 0.7324333	total: 13.3s	remaining: 54.1s
# 594:	learn: 0.7324023	total: 13.4s	remaining: 54s
# 595:	learn: 0.7323847	total: 13.4s	remaining: 54s
# 596:	learn: 0.7323523	total: 13.4s	remaining: 54s
# 597:	learn: 0.7323392	total: 13.4s	remaining: 53.9s
# 598:	learn: 0.7322975	total: 13.4s	remaining: 53.9s
# 599:	learn: 0.7322744	total: 13.5s	remaining: 53.9s
# 600:	learn: 0.7322284	total: 13.5s	remaining: 53.9s
# 601:	learn: 0.7321792	total: 13.5s	remaining: 53.8s
# 602:	learn: 0.7321366	total: 13.5s	remaining: 53.8s
# 603:	learn: 0.7321075	total: 13.6s	remaining: 53.8s
# 604:	learn: 0.7320862	total: 13.6s	remaining: 53.8s
# 605:	learn: 0.7320484	total: 13.6s	remaining: 53.7s
# 606:	learn: 0.7320101	total: 13.6s	remaining: 53.7s
# 607:	learn: 0.7319676	total: 13.6s	remaining: 53.7s
# 608:	learn: 0.7319430	total: 13.7s	remaining: 53.7s
# 609:	learn: 0.7319168	total: 13.7s	remaining: 53.6s
# 610:	learn: 0.7318733	total: 13.7s	remaining: 53.6s
# 611:	learn: 0.7318402	total: 13.7s	remaining: 53.6s
# 612:	learn: 0.7317689	total: 13.8s	remaining: 53.6s
# 613:	learn: 0.7317591	total: 13.8s	remaining: 53.5s
# 614:	learn: 0.7317350	total: 13.8s	remaining: 53.5s
# 615:	learn: 0.7317048	total: 13.8s	remaining: 53.5s
# 616:	learn: 0.7316806	total: 13.8s	remaining: 53.5s
# 617:	learn: 0.7316140	total: 13.9s	remaining: 53.5s
# 618:	learn: 0.7315600	total: 13.9s	remaining: 53.4s
# 619:	learn: 0.7315363	total: 13.9s	remaining: 53.4s
# 620:	learn: 0.7314930	total: 13.9s	remaining: 53.4s
# 621:	learn: 0.7314519	total: 14s	remaining: 53.3s
# 622:	learn: 0.7314138	total: 14s	remaining: 53.3s
# 623:	learn: 0.7313421	total: 14s	remaining: 53.3s
# 624:	learn: 0.7313077	total: 14s	remaining: 53.3s
# 625:	learn: 0.7312400	total: 14s	remaining: 53.3s
# 626:	learn: 0.7312163	total: 14.1s	remaining: 53.2s
# 627:	learn: 0.7311859	total: 14.1s	remaining: 53.2s
# 628:	learn: 0.7311418	total: 14.1s	remaining: 53.2s
# 629:	learn: 0.7311189	total: 14.1s	remaining: 53.1s
# 630:	learn: 0.7310810	total: 14.1s	remaining: 53.1s
# 631:	learn: 0.7310351	total: 14.2s	remaining: 53.1s
# 632:	learn: 0.7310002	total: 14.2s	remaining: 53.1s
# 633:	learn: 0.7309162	total: 14.2s	remaining: 53s
# 634:	learn: 0.7308683	total: 14.2s	remaining: 53s
# 635:	learn: 0.7308106	total: 14.3s	remaining: 53s
# 636:	learn: 0.7307561	total: 14.3s	remaining: 53s
# 637:	learn: 0.7307291	total: 14.3s	remaining: 53s
# 638:	learn: 0.7306804	total: 14.3s	remaining: 52.9s
# 639:	learn: 0.7306548	total: 14.3s	remaining: 52.9s
# 640:	learn: 0.7306151	total: 14.4s	remaining: 52.9s
# 641:	learn: 0.7305316	total: 14.4s	remaining: 52.9s
# 642:	learn: 0.7304574	total: 14.4s	remaining: 52.8s
# 643:	learn: 0.7304195	total: 14.4s	remaining: 52.8s
# 644:	learn: 0.7303867	total: 14.5s	remaining: 52.8s
# 645:	learn: 0.7303571	total: 14.5s	remaining: 52.8s
# 646:	learn: 0.7303190	total: 14.5s	remaining: 52.7s
# 647:	learn: 0.7302399	total: 14.5s	remaining: 52.7s
# 648:	learn: 0.7302165	total: 14.5s	remaining: 52.7s
# 649:	learn: 0.7301911	total: 14.6s	remaining: 52.7s
# 650:	learn: 0.7301279	total: 14.6s	remaining: 52.6s
# 651:	learn: 0.7301137	total: 14.6s	remaining: 52.6s
# 652:	learn: 0.7300783	total: 14.6s	remaining: 52.6s
# 653:	learn: 0.7300337	total: 14.6s	remaining: 52.5s
# 654:	learn: 0.7300033	total: 14.7s	remaining: 52.5s
# 655:	learn: 0.7299856	total: 14.7s	remaining: 52.5s
# 656:	learn: 0.7299436	total: 14.7s	remaining: 52.5s
# 657:	learn: 0.7299234	total: 14.7s	remaining: 52.4s
# 658:	learn: 0.7298632	total: 14.8s	remaining: 52.4s
# 659:	learn: 0.7297690	total: 14.8s	remaining: 52.4s
# 660:	learn: 0.7297203	total: 14.8s	remaining: 52.4s
# 661:	learn: 0.7296869	total: 14.8s	remaining: 52.4s
# 662:	learn: 0.7296678	total: 14.8s	remaining: 52.3s
# 663:	learn: 0.7296350	total: 14.9s	remaining: 52.3s
# 664:	learn: 0.7295931	total: 14.9s	remaining: 52.3s
# 665:	learn: 0.7295644	total: 14.9s	remaining: 52.3s
# 666:	learn: 0.7295476	total: 14.9s	remaining: 52.2s
# 667:	learn: 0.7294953	total: 15s	remaining: 52.2s
# 668:	learn: 0.7294693	total: 15s	remaining: 52.2s
# 669:	learn: 0.7294129	total: 15s	remaining: 52.2s
# 670:	learn: 0.7293897	total: 15s	remaining: 52.1s
# 671:	learn: 0.7293582	total: 15s	remaining: 52.1s
# 672:	learn: 0.7293394	total: 15.1s	remaining: 52.1s
# 673:	learn: 0.7293276	total: 15.1s	remaining: 52.1s
# 674:	learn: 0.7292817	total: 15.1s	remaining: 52.1s
# 675:	learn: 0.7292138	total: 15.1s	remaining: 52s
# 676:	learn: 0.7291748	total: 15.2s	remaining: 52s
# 677:	learn: 0.7291452	total: 15.2s	remaining: 52s
# 678:	learn: 0.7290848	total: 15.2s	remaining: 52s
# 679:	learn: 0.7290421	total: 15.2s	remaining: 51.9s
# 680:	learn: 0.7290204	total: 15.2s	remaining: 51.9s
# 681:	learn: 0.7289801	total: 15.3s	remaining: 51.9s
# 682:	learn: 0.7289429	total: 15.3s	remaining: 51.8s
# 683:	learn: 0.7289033	total: 15.3s	remaining: 51.8s
# 684:	learn: 0.7288880	total: 15.3s	remaining: 51.8s
# 685:	learn: 0.7288424	total: 15.3s	remaining: 51.8s
# 686:	learn: 0.7288279	total: 15.4s	remaining: 51.7s
# 687:	learn: 0.7287899	total: 15.4s	remaining: 51.7s
# 688:	learn: 0.7287552	total: 15.4s	remaining: 51.7s
# 689:	learn: 0.7287265	total: 15.4s	remaining: 51.7s
# 690:	learn: 0.7286915	total: 15.5s	remaining: 51.6s
# 691:	learn: 0.7286620	total: 15.5s	remaining: 51.6s
# 692:	learn: 0.7285967	total: 15.5s	remaining: 51.6s
# 693:	learn: 0.7285655	total: 15.5s	remaining: 51.6s
# 694:	learn: 0.7285227	total: 15.5s	remaining: 51.5s
# 695:	learn: 0.7284922	total: 15.6s	remaining: 51.5s
# 696:	learn: 0.7284512	total: 15.6s	remaining: 51.5s
# 697:	learn: 0.7284226	total: 15.6s	remaining: 51.5s
# 698:	learn: 0.7283741	total: 15.6s	remaining: 51.5s
# 699:	learn: 0.7283226	total: 15.6s	remaining: 51.4s
# 700:	learn: 0.7282962	total: 15.7s	remaining: 51.4s
# 701:	learn: 0.7282746	total: 15.7s	remaining: 51.4s
# 702:	learn: 0.7282623	total: 15.7s	remaining: 51.3s
# 703:	learn: 0.7282213	total: 15.7s	remaining: 51.3s
# 704:	learn: 0.7282032	total: 15.8s	remaining: 51.3s
# 705:	learn: 0.7281684	total: 15.8s	remaining: 51.3s
# 706:	learn: 0.7281390	total: 15.8s	remaining: 51.2s
# 707:	learn: 0.7281068	total: 15.8s	remaining: 51.2s
# 708:	learn: 0.7280962	total: 15.8s	remaining: 51.2s
# 709:	learn: 0.7280801	total: 15.9s	remaining: 51.2s
# 710:	learn: 0.7280480	total: 15.9s	remaining: 51.1s
# 711:	learn: 0.7280035	total: 15.9s	remaining: 51.1s
# 712:	learn: 0.7279683	total: 15.9s	remaining: 51.1s
# 713:	learn: 0.7279158	total: 16s	remaining: 51.1s
# 714:	learn: 0.7279001	total: 16s	remaining: 51.1s
# 715:	learn: 0.7278543	total: 16s	remaining: 51s
# 716:	learn: 0.7278308	total: 16s	remaining: 51s
# 717:	learn: 0.7277799	total: 16s	remaining: 51s
# 718:	learn: 0.7277439	total: 16.1s	remaining: 51s
# 719:	learn: 0.7277003	total: 16.1s	remaining: 50.9s
# 720:	learn: 0.7276915	total: 16.1s	remaining: 50.9s
# 721:	learn: 0.7276724	total: 16.1s	remaining: 50.9s
# 722:	learn: 0.7276440	total: 16.1s	remaining: 50.9s
# 723:	learn: 0.7275902	total: 16.2s	remaining: 50.8s
# 724:	learn: 0.7275542	total: 16.2s	remaining: 50.8s
# 725:	learn: 0.7275169	total: 16.2s	remaining: 50.8s
# 726:	learn: 0.7274564	total: 16.2s	remaining: 50.8s
# 727:	learn: 0.7274088	total: 16.3s	remaining: 50.7s
# 728:	learn: 0.7273698	total: 16.3s	remaining: 50.7s
# 729:	learn: 0.7273403	total: 16.3s	remaining: 50.7s
# 730:	learn: 0.7272928	total: 16.3s	remaining: 50.7s
# 731:	learn: 0.7272739	total: 16.3s	remaining: 50.6s
# 732:	learn: 0.7272493	total: 16.4s	remaining: 50.6s
# 733:	learn: 0.7272225	total: 16.4s	remaining: 50.6s
# 734:	learn: 0.7272029	total: 16.4s	remaining: 50.6s
# 735:	learn: 0.7271293	total: 16.4s	remaining: 50.6s
# 736:	learn: 0.7271013	total: 16.5s	remaining: 50.5s
# 737:	learn: 0.7270797	total: 16.5s	remaining: 50.5s
# 738:	learn: 0.7270506	total: 16.5s	remaining: 50.5s
# 739:	learn: 0.7270266	total: 16.5s	remaining: 50.5s
# 740:	learn: 0.7269992	total: 16.5s	remaining: 50.4s
# 741:	learn: 0.7269481	total: 16.6s	remaining: 50.4s
# 742:	learn: 0.7268799	total: 16.6s	remaining: 50.4s
# 743:	learn: 0.7268656	total: 16.6s	remaining: 50.4s
# 744:	learn: 0.7268360	total: 16.6s	remaining: 50.4s
# 745:	learn: 0.7267789	total: 16.7s	remaining: 50.3s
# 746:	learn: 0.7267261	total: 16.7s	remaining: 50.3s
# 747:	learn: 0.7266763	total: 16.7s	remaining: 50.3s
# 748:	learn: 0.7266216	total: 16.7s	remaining: 50.3s
# 749:	learn: 0.7265935	total: 16.7s	remaining: 50.2s
# 750:	learn: 0.7265520	total: 16.8s	remaining: 50.2s
# 751:	learn: 0.7265215	total: 16.8s	remaining: 50.2s
# 752:	learn: 0.7265053	total: 16.8s	remaining: 50.2s
# 753:	learn: 0.7264615	total: 16.8s	remaining: 50.1s
# 754:	learn: 0.7264440	total: 16.9s	remaining: 50.1s
# 755:	learn: 0.7263846	total: 16.9s	remaining: 50.1s
# 756:	learn: 0.7263531	total: 16.9s	remaining: 50.1s
# 757:	learn: 0.7263079	total: 16.9s	remaining: 50s
# 758:	learn: 0.7262997	total: 16.9s	remaining: 50s
# 759:	learn: 0.7262607	total: 17s	remaining: 50s
# 760:	learn: 0.7262348	total: 17s	remaining: 50s
# 761:	learn: 0.7262131	total: 17s	remaining: 49.9s
# 762:	learn: 0.7261948	total: 17s	remaining: 49.9s
# 763:	learn: 0.7261677	total: 17s	remaining: 49.9s
# 764:	learn: 0.7261368	total: 17.1s	remaining: 49.9s
# 765:	learn: 0.7260920	total: 17.1s	remaining: 49.8s
# 766:	learn: 0.7260676	total: 17.1s	remaining: 49.8s
# 767:	learn: 0.7260416	total: 17.1s	remaining: 49.8s
# 768:	learn: 0.7260216	total: 17.2s	remaining: 49.8s
# 769:	learn: 0.7259805	total: 17.2s	remaining: 49.7s
# 770:	learn: 0.7259442	total: 17.2s	remaining: 49.7s
# 771:	learn: 0.7259210	total: 17.2s	remaining: 49.7s
# 772:	learn: 0.7258973	total: 17.2s	remaining: 49.7s
# 773:	learn: 0.7258793	total: 17.3s	remaining: 49.7s
# 774:	learn: 0.7258593	total: 17.3s	remaining: 49.6s
# 775:	learn: 0.7258246	total: 17.3s	remaining: 49.6s
# 776:	learn: 0.7258082	total: 17.3s	remaining: 49.6s
# 777:	learn: 0.7257896	total: 17.3s	remaining: 49.5s
# 778:	learn: 0.7257725	total: 17.4s	remaining: 49.5s
# 779:	learn: 0.7257326	total: 17.4s	remaining: 49.5s
# 780:	learn: 0.7257004	total: 17.4s	remaining: 49.5s
# 781:	learn: 0.7256613	total: 17.4s	remaining: 49.5s
# 782:	learn: 0.7256260	total: 17.5s	remaining: 49.4s
# 783:	learn: 0.7255981	total: 17.5s	remaining: 49.4s
# 784:	learn: 0.7255707	total: 17.5s	remaining: 49.4s
# 785:	learn: 0.7255252	total: 17.5s	remaining: 49.4s
# 786:	learn: 0.7254845	total: 17.5s	remaining: 49.3s
# 787:	learn: 0.7254661	total: 17.6s	remaining: 49.3s
# 788:	learn: 0.7254242	total: 17.6s	remaining: 49.3s
# 789:	learn: 0.7253558	total: 17.6s	remaining: 49.3s
# 790:	learn: 0.7253233	total: 17.6s	remaining: 49.2s
# 791:	learn: 0.7253063	total: 17.7s	remaining: 49.2s
# 792:	learn: 0.7252828	total: 17.7s	remaining: 49.2s
# 793:	learn: 0.7252440	total: 17.7s	remaining: 49.2s
# 794:	learn: 0.7251952	total: 17.7s	remaining: 49.2s
# 795:	learn: 0.7251606	total: 17.7s	remaining: 49.1s
# 796:	learn: 0.7251299	total: 17.8s	remaining: 49.1s
# 797:	learn: 0.7251152	total: 17.8s	remaining: 49.1s
# 798:	learn: 0.7250866	total: 17.8s	remaining: 49s
# 799:	learn: 0.7250455	total: 17.8s	remaining: 49s
# 800:	learn: 0.7250080	total: 17.9s	remaining: 49s
# 801:	learn: 0.7249671	total: 17.9s	remaining: 49s
# 802:	learn: 0.7249492	total: 17.9s	remaining: 49s
# 803:	learn: 0.7249313	total: 17.9s	remaining: 48.9s
# 804:	learn: 0.7248925	total: 17.9s	remaining: 48.9s
# 805:	learn: 0.7248581	total: 18s	remaining: 48.9s
# 806:	learn: 0.7248255	total: 18s	remaining: 48.9s
# 807:	learn: 0.7247951	total: 18s	remaining: 48.8s
# 808:	learn: 0.7247313	total: 18s	remaining: 48.8s
# 809:	learn: 0.7246979	total: 18s	remaining: 48.8s
# 810:	learn: 0.7246659	total: 18.1s	remaining: 48.8s
# 811:	learn: 0.7245998	total: 18.1s	remaining: 48.8s
# 812:	learn: 0.7245706	total: 18.1s	remaining: 48.7s
# 813:	learn: 0.7245410	total: 18.1s	remaining: 48.7s
# 814:	learn: 0.7245249	total: 18.2s	remaining: 48.7s
# 815:	learn: 0.7245119	total: 18.2s	remaining: 48.7s
# 816:	learn: 0.7244596	total: 18.2s	remaining: 48.6s
# 817:	learn: 0.7244262	total: 18.2s	remaining: 48.6s
# 818:	learn: 0.7243802	total: 18.2s	remaining: 48.6s
# 819:	learn: 0.7243389	total: 18.3s	remaining: 48.6s
# 820:	learn: 0.7243181	total: 18.3s	remaining: 48.5s
# 821:	learn: 0.7242950	total: 18.3s	remaining: 48.5s
# 822:	learn: 0.7242719	total: 18.3s	remaining: 48.5s
# 823:	learn: 0.7242302	total: 18.3s	remaining: 48.5s
# 824:	learn: 0.7241896	total: 18.4s	remaining: 48.4s
# 825:	learn: 0.7241712	total: 18.4s	remaining: 48.4s
# 826:	learn: 0.7241516	total: 18.4s	remaining: 48.4s
# 827:	learn: 0.7241267	total: 18.4s	remaining: 48.4s
# 828:	learn: 0.7240971	total: 18.5s	remaining: 48.3s
# 829:	learn: 0.7240560	total: 18.5s	remaining: 48.3s
# 830:	learn: 0.7240309	total: 18.5s	remaining: 48.3s
# 831:	learn: 0.7239948	total: 18.5s	remaining: 48.3s
# 832:	learn: 0.7239644	total: 18.5s	remaining: 48.2s
# 833:	learn: 0.7239462	total: 18.6s	remaining: 48.2s
# 834:	learn: 0.7239225	total: 18.6s	remaining: 48.2s
# 835:	learn: 0.7238778	total: 18.6s	remaining: 48.2s
# 836:	learn: 0.7238615	total: 18.6s	remaining: 48.1s
# 837:	learn: 0.7237938	total: 18.6s	remaining: 48.1s
# 838:	learn: 0.7237764	total: 18.7s	remaining: 48.1s
# 839:	learn: 0.7237706	total: 18.7s	remaining: 48.1s
# 840:	learn: 0.7237432	total: 18.7s	remaining: 48s
# 841:	learn: 0.7237247	total: 18.7s	remaining: 48s
# 842:	learn: 0.7236843	total: 18.8s	remaining: 48s
# 843:	learn: 0.7236558	total: 18.8s	remaining: 48s
# 844:	learn: 0.7236398	total: 18.8s	remaining: 47.9s
# 845:	learn: 0.7236049	total: 18.8s	remaining: 47.9s
# 846:	learn: 0.7235886	total: 18.8s	remaining: 47.9s
# 847:	learn: 0.7235168	total: 18.9s	remaining: 47.9s
# 848:	learn: 0.7234935	total: 18.9s	remaining: 47.8s
# 849:	learn: 0.7234696	total: 18.9s	remaining: 47.8s
# 850:	learn: 0.7234421	total: 18.9s	remaining: 47.8s
# 851:	learn: 0.7234138	total: 18.9s	remaining: 47.8s
# 852:	learn: 0.7234073	total: 19s	remaining: 47.8s
# 853:	learn: 0.7233691	total: 19s	remaining: 47.7s
# 854:	learn: 0.7233437	total: 19s	remaining: 47.7s
# 855:	learn: 0.7233252	total: 19s	remaining: 47.7s
# 856:	learn: 0.7232805	total: 19.1s	remaining: 47.7s
# 857:	learn: 0.7232538	total: 19.1s	remaining: 47.6s
# 858:	learn: 0.7232115	total: 19.1s	remaining: 47.6s
# 859:	learn: 0.7231787	total: 19.1s	remaining: 47.6s
# 860:	learn: 0.7231292	total: 19.1s	remaining: 47.6s
# 861:	learn: 0.7230991	total: 19.2s	remaining: 47.5s
# 862:	learn: 0.7230641	total: 19.2s	remaining: 47.5s
# 863:	learn: 0.7230537	total: 19.2s	remaining: 47.5s
# 864:	learn: 0.7230388	total: 19.2s	remaining: 47.5s
# 865:	learn: 0.7230028	total: 19.3s	remaining: 47.4s
# 866:	learn: 0.7229723	total: 19.3s	remaining: 47.4s
# 867:	learn: 0.7229218	total: 19.3s	remaining: 47.4s
# 868:	learn: 0.7228843	total: 19.3s	remaining: 47.4s
# 869:	learn: 0.7228420	total: 19.3s	remaining: 47.3s
# 870:	learn: 0.7228230	total: 19.4s	remaining: 47.3s
# 871:	learn: 0.7228066	total: 19.4s	remaining: 47.3s
# 872:	learn: 0.7228009	total: 19.4s	remaining: 47.3s
# 873:	learn: 0.7227707	total: 19.4s	remaining: 47.2s
# 874:	learn: 0.7227387	total: 19.4s	remaining: 47.2s
# 875:	learn: 0.7227038	total: 19.5s	remaining: 47.2s
# 876:	learn: 0.7226934	total: 19.5s	remaining: 47.2s
# 877:	learn: 0.7226806	total: 19.5s	remaining: 47.1s
# 878:	learn: 0.7226585	total: 19.5s	remaining: 47.1s
# 879:	learn: 0.7226101	total: 19.6s	remaining: 47.1s
# 880:	learn: 0.7225954	total: 19.6s	remaining: 47.1s
# 881:	learn: 0.7225795	total: 19.6s	remaining: 47.1s
# 882:	learn: 0.7225476	total: 19.6s	remaining: 47s
# 883:	learn: 0.7225149	total: 19.6s	remaining: 47s
# 884:	learn: 0.7224818	total: 19.7s	remaining: 47s
# 885:	learn: 0.7224610	total: 19.7s	remaining: 47s
# 886:	learn: 0.7224469	total: 19.7s	remaining: 46.9s
# 887:	learn: 0.7224241	total: 19.7s	remaining: 46.9s
# 888:	learn: 0.7223940	total: 19.7s	remaining: 46.9s
# 889:	learn: 0.7223733	total: 19.8s	remaining: 46.9s
# 890:	learn: 0.7223421	total: 19.8s	remaining: 46.8s
# 891:	learn: 0.7223236	total: 19.8s	remaining: 46.8s
# 892:	learn: 0.7222810	total: 19.8s	remaining: 46.8s
# 893:	learn: 0.7222623	total: 19.8s	remaining: 46.8s
# 894:	learn: 0.7222570	total: 19.9s	remaining: 46.7s
# 895:	learn: 0.7222197	total: 19.9s	remaining: 46.7s
# 896:	learn: 0.7221953	total: 19.9s	remaining: 46.7s
# 897:	learn: 0.7221751	total: 19.9s	remaining: 46.7s
# 898:	learn: 0.7221551	total: 20s	remaining: 46.6s
# 899:	learn: 0.7221238	total: 20s	remaining: 46.6s
# 900:	learn: 0.7221083	total: 20s	remaining: 46.6s
# 901:	learn: 0.7220979	total: 20s	remaining: 46.6s
# 902:	learn: 0.7220553	total: 20s	remaining: 46.5s
# 903:	learn: 0.7220035	total: 20.1s	remaining: 46.5s
# 904:	learn: 0.7219721	total: 20.1s	remaining: 46.5s
# 905:	learn: 0.7219133	total: 20.1s	remaining: 46.5s
# 906:	learn: 0.7218658	total: 20.1s	remaining: 46.5s
# 907:	learn: 0.7218166	total: 20.2s	remaining: 46.4s
# 908:	learn: 0.7217593	total: 20.2s	remaining: 46.4s
# 909:	learn: 0.7217295	total: 20.2s	remaining: 46.4s
# 910:	learn: 0.7216987	total: 20.2s	remaining: 46.4s
# 911:	learn: 0.7216652	total: 20.2s	remaining: 46.3s
# 912:	learn: 0.7216368	total: 20.3s	remaining: 46.3s
# 913:	learn: 0.7216089	total: 20.3s	remaining: 46.3s
# 914:	learn: 0.7215850	total: 20.3s	remaining: 46.3s
# 915:	learn: 0.7215541	total: 20.3s	remaining: 46.2s
# 916:	learn: 0.7215193	total: 20.4s	remaining: 46.2s
# 917:	learn: 0.7215012	total: 20.4s	remaining: 46.2s
# 918:	learn: 0.7214706	total: 20.4s	remaining: 46.2s
# 919:	learn: 0.7214432	total: 20.4s	remaining: 46.2s
# 920:	learn: 0.7214290	total: 20.4s	remaining: 46.1s
# 921:	learn: 0.7213915	total: 20.5s	remaining: 46.1s
# 922:	learn: 0.7213764	total: 20.5s	remaining: 46.1s
# 923:	learn: 0.7213416	total: 20.5s	remaining: 46.1s
# 924:	learn: 0.7213222	total: 20.5s	remaining: 46s
# 925:	learn: 0.7212799	total: 20.5s	remaining: 46s
# 926:	learn: 0.7212493	total: 20.6s	remaining: 46s
# 927:	learn: 0.7212104	total: 20.6s	remaining: 46s
# 928:	learn: 0.7211982	total: 20.6s	remaining: 45.9s
# 929:	learn: 0.7211479	total: 20.6s	remaining: 45.9s
# 930:	learn: 0.7210871	total: 20.7s	remaining: 45.9s
# ...
# 2695:	learn: 0.6850554	total: 58.7s	remaining: 6.62s
# 2696:	learn: 0.6850514	total: 58.7s	remaining: 6.59s
# 2697:	learn: 0.6850428	total: 58.7s	remaining: 6.57s
# 2698:	learn: 0.6850276	total: 58.7s	remaining: 6.55s
# 2699:	learn: 0.6850043	total: 58.8s	remaining: 6.53s
# 2700:	learn: 0.6849922	total: 58.8s	remaining: 6.51s
# 2701:	learn: 0.6849856	total: 58.8s	remaining: 6.49s
# 2702:	learn: 0.6849654	total: 58.8s	remaining: 6.46s
# 2703:	learn: 0.6849280	total: 58.9s	remaining: 6.44s
# 2704:	learn: 0.6849151	total: 58.9s	remaining: 6.42s
# 2705:	learn: 0.6849131	total: 58.9s	remaining: 6.4s
# 2706:	learn: 0.6848765	total: 58.9s	remaining: 6.38s
# 2707:	learn: 0.6848566	total: 58.9s	remaining: 6.36s
# 2708:	learn: 0.6848294	total: 59s	remaining: 6.33s
# 2709:	learn: 0.6848180	total: 59s	remaining: 6.31s
# 2710:	learn: 0.6848004	total: 59s	remaining: 6.29s
# 2711:	learn: 0.6847734	total: 59s	remaining: 6.27s
# 2712:	learn: 0.6847526	total: 59.1s	remaining: 6.25s
# 2713:	learn: 0.6847520	total: 59.1s	remaining: 6.22s
# 2714:	learn: 0.6847233	total: 59.1s	remaining: 6.2s
# 2715:	learn: 0.6847204	total: 59.1s	remaining: 6.18s
# 2716:	learn: 0.6847043	total: 59.1s	remaining: 6.16s
# 2717:	learn: 0.6846891	total: 59.2s	remaining: 6.14s
# 2718:	learn: 0.6846665	total: 59.2s	remaining: 6.12s
# 2719:	learn: 0.6846337	total: 59.2s	remaining: 6.09s
# 2720:	learn: 0.6846173	total: 59.2s	remaining: 6.07s
# 2721:	learn: 0.6845806	total: 59.2s	remaining: 6.05s
# 2722:	learn: 0.6845740	total: 59.3s	remaining: 6.03s
# 2723:	learn: 0.6845354	total: 59.3s	remaining: 6.01s
# 2724:	learn: 0.6845079	total: 59.3s	remaining: 5.99s
# 2725:	learn: 0.6844880	total: 59.3s	remaining: 5.96s
# 2726:	learn: 0.6844778	total: 59.4s	remaining: 5.94s
# 2727:	learn: 0.6844661	total: 59.4s	remaining: 5.92s
# 2728:	learn: 0.6844401	total: 59.4s	remaining: 5.9s
# 2729:	learn: 0.6844097	total: 59.4s	remaining: 5.88s
# 2730:	learn: 0.6843907	total: 59.4s	remaining: 5.86s
# 2731:	learn: 0.6843591	total: 59.5s	remaining: 5.83s
# 2732:	learn: 0.6843422	total: 59.5s	remaining: 5.81s
# 2733:	learn: 0.6843304	total: 59.5s	remaining: 5.79s
# 2734:	learn: 0.6843193	total: 59.5s	remaining: 5.77s
# 2735:	learn: 0.6842978	total: 59.6s	remaining: 5.75s
# 2736:	learn: 0.6842898	total: 59.6s	remaining: 5.72s
# 2737:	learn: 0.6842695	total: 59.6s	remaining: 5.7s
# 2738:	learn: 0.6842489	total: 59.6s	remaining: 5.68s
# 2739:	learn: 0.6842355	total: 59.6s	remaining: 5.66s
# 2740:	learn: 0.6842286	total: 59.7s	remaining: 5.64s
# 2741:	learn: 0.6842261	total: 59.7s	remaining: 5.62s
# 2742:	learn: 0.6842106	total: 59.7s	remaining: 5.59s
# 2743:	learn: 0.6841852	total: 59.7s	remaining: 5.57s
# 2744:	learn: 0.6841677	total: 59.7s	remaining: 5.55s
# 2745:	learn: 0.6841560	total: 59.8s	remaining: 5.53s
# 2746:	learn: 0.6841414	total: 59.8s	remaining: 5.51s
# 2747:	learn: 0.6840928	total: 59.8s	remaining: 5.49s
# 2748:	learn: 0.6840858	total: 59.8s	remaining: 5.46s
# 2749:	learn: 0.6840646	total: 59.9s	remaining: 5.44s
# 2750:	learn: 0.6840519	total: 59.9s	remaining: 5.42s
# 2751:	learn: 0.6840407	total: 59.9s	remaining: 5.4s
# 2752:	learn: 0.6840154	total: 59.9s	remaining: 5.38s
# 2753:	learn: 0.6839714	total: 59.9s	remaining: 5.35s
# 2754:	learn: 0.6839555	total: 60s	remaining: 5.33s
# 2755:	learn: 0.6839505	total: 60s	remaining: 5.31s
# 2756:	learn: 0.6839415	total: 1m	remaining: 5.29s
# 2757:	learn: 0.6839345	total: 1m	remaining: 5.27s
# 2758:	learn: 0.6839234	total: 1m	remaining: 5.25s
# 2759:	learn: 0.6839109	total: 1m	remaining: 5.22s
# 2760:	learn: 0.6838936	total: 1m	remaining: 5.2s
# 2761:	learn: 0.6838785	total: 1m	remaining: 5.18s
# 2762:	learn: 0.6838633	total: 1m	remaining: 5.16s
# 2763:	learn: 0.6838577	total: 1m	remaining: 5.14s
# 2764:	learn: 0.6838377	total: 1m	remaining: 5.12s
# 2765:	learn: 0.6838045	total: 1m	remaining: 5.09s
# 2766:	learn: 0.6837784	total: 1m	remaining: 5.07s
# 2767:	learn: 0.6837605	total: 1m	remaining: 5.05s
# 2768:	learn: 0.6837512	total: 1m	remaining: 5.03s
# 2769:	learn: 0.6837406	total: 1m	remaining: 5.01s
# 2770:	learn: 0.6837271	total: 1m	remaining: 4.98s
# 2771:	learn: 0.6837151	total: 1m	remaining: 4.96s
# 2772:	learn: 0.6836953	total: 1m	remaining: 4.94s
# 2773:	learn: 0.6836870	total: 1m	remaining: 4.92s
# 2774:	learn: 0.6836688	total: 1m	remaining: 4.9s
# 2775:	learn: 0.6836514	total: 1m	remaining: 4.88s
# 2776:	learn: 0.6836324	total: 1m	remaining: 4.85s
# 2777:	learn: 0.6836128	total: 1m	remaining: 4.83s
# 2778:	learn: 0.6835781	total: 1m	remaining: 4.81s
# 2779:	learn: 0.6835717	total: 1m	remaining: 4.79s
# 2780:	learn: 0.6835411	total: 1m	remaining: 4.77s
# 2781:	learn: 0.6835205	total: 1m	remaining: 4.75s
# 2782:	learn: 0.6834924	total: 1m	remaining: 4.72s
# 2783:	learn: 0.6834677	total: 1m	remaining: 4.7s
# 2784:	learn: 0.6834497	total: 1m	remaining: 4.68s
# 2785:	learn: 0.6834276	total: 1m	remaining: 4.66s
# 2786:	learn: 0.6834095	total: 1m	remaining: 4.64s
# 2787:	learn: 0.6833848	total: 1m	remaining: 4.61s
# 2788:	learn: 0.6833751	total: 1m	remaining: 4.59s
# 2789:	learn: 0.6833625	total: 1m	remaining: 4.57s
# 2790:	learn: 0.6833478	total: 1m	remaining: 4.55s
# 2791:	learn: 0.6833276	total: 1m	remaining: 4.53s
# 2792:	learn: 0.6833149	total: 1m	remaining: 4.5s
# 2793:	learn: 0.6833024	total: 1m	remaining: 4.48s
# 2794:	learn: 0.6832748	total: 1m	remaining: 4.46s
# 2795:	learn: 0.6832653	total: 1m	remaining: 4.44s
# 2796:	learn: 0.6832396	total: 1m	remaining: 4.42s
# 2797:	learn: 0.6832157	total: 1m	remaining: 4.4s
# 2798:	learn: 0.6831834	total: 1m	remaining: 4.38s
# 2799:	learn: 0.6831681	total: 1m	remaining: 4.35s
# 2800:	learn: 0.6831444	total: 1m	remaining: 4.33s
# 2801:	learn: 0.6831305	total: 1m	remaining: 4.31s
# 2802:	learn: 0.6831107	total: 1m 1s	remaining: 4.29s
# 2803:	learn: 0.6830850	total: 1m 1s	remaining: 4.27s
# 2804:	learn: 0.6830705	total: 1m 1s	remaining: 4.24s
# 2805:	learn: 0.6830576	total: 1m 1s	remaining: 4.22s
# 2806:	learn: 0.6830484	total: 1m 1s	remaining: 4.2s
# 2807:	learn: 0.6830179	total: 1m 1s	remaining: 4.18s
# 2808:	learn: 0.6830117	total: 1m 1s	remaining: 4.16s
# 2809:	learn: 0.6830018	total: 1m 1s	remaining: 4.13s
# 2810:	learn: 0.6829893	total: 1m 1s	remaining: 4.11s
# 2811:	learn: 0.6829782	total: 1m 1s	remaining: 4.09s
# 2812:	learn: 0.6829635	total: 1m 1s	remaining: 4.07s
# 2813:	learn: 0.6829441	total: 1m 1s	remaining: 4.05s
# 2814:	learn: 0.6829351	total: 1m 1s	remaining: 4.03s
# 2815:	learn: 0.6829146	total: 1m 1s	remaining: 4s
# 2816:	learn: 0.6829045	total: 1m 1s	remaining: 3.98s
# 2817:	learn: 0.6828698	total: 1m 1s	remaining: 3.96s
# 2818:	learn: 0.6828488	total: 1m 1s	remaining: 3.94s
# 2819:	learn: 0.6828250	total: 1m 1s	remaining: 3.92s
# 2820:	learn: 0.6828214	total: 1m 1s	remaining: 3.9s
# 2821:	learn: 0.6828027	total: 1m 1s	remaining: 3.87s
# 2822:	learn: 0.6827737	total: 1m 1s	remaining: 3.85s
# 2823:	learn: 0.6827499	total: 1m 1s	remaining: 3.83s
# 2824:	learn: 0.6827205	total: 1m 1s	remaining: 3.81s
# 2825:	learn: 0.6827033	total: 1m 1s	remaining: 3.79s
# 2826:	learn: 0.6826845	total: 1m 1s	remaining: 3.77s
# 2827:	learn: 0.6826671	total: 1m 1s	remaining: 3.74s
# 2828:	learn: 0.6826523	total: 1m 1s	remaining: 3.72s
# 2829:	learn: 0.6826305	total: 1m 1s	remaining: 3.7s
# 2830:	learn: 0.6826093	total: 1m 1s	remaining: 3.68s
# 2831:	learn: 0.6825969	total: 1m 1s	remaining: 3.66s
# 2832:	learn: 0.6825756	total: 1m 1s	remaining: 3.63s
# 2833:	learn: 0.6825557	total: 1m 1s	remaining: 3.61s
# 2834:	learn: 0.6825495	total: 1m 1s	remaining: 3.59s
# 2835:	learn: 0.6825371	total: 1m 1s	remaining: 3.57s
# 2836:	learn: 0.6825234	total: 1m 1s	remaining: 3.55s
# 2837:	learn: 0.6825125	total: 1m 1s	remaining: 3.53s
# 2838:	learn: 0.6824823	total: 1m 1s	remaining: 3.5s
# 2839:	learn: 0.6824430	total: 1m 1s	remaining: 3.48s
# 2840:	learn: 0.6824248	total: 1m 1s	remaining: 3.46s
# 2841:	learn: 0.6824162	total: 1m 1s	remaining: 3.44s
# 2842:	learn: 0.6823962	total: 1m 1s	remaining: 3.42s
# 2843:	learn: 0.6823853	total: 1m 1s	remaining: 3.4s
# 2844:	learn: 0.6823741	total: 1m 1s	remaining: 3.37s
# 2845:	learn: 0.6823506	total: 1m 1s	remaining: 3.35s
# 2846:	learn: 0.6823320	total: 1m 1s	remaining: 3.33s
# 2847:	learn: 0.6823068	total: 1m 1s	remaining: 3.31s
# 2848:	learn: 0.6822907	total: 1m 2s	remaining: 3.29s
# 2849:	learn: 0.6822677	total: 1m 2s	remaining: 3.27s
# 2850:	learn: 0.6822590	total: 1m 2s	remaining: 3.24s
# 2851:	learn: 0.6822492	total: 1m 2s	remaining: 3.22s
# 2852:	learn: 0.6822355	total: 1m 2s	remaining: 3.2s
# 2853:	learn: 0.6822145	total: 1m 2s	remaining: 3.18s
# 2854:	learn: 0.6822054	total: 1m 2s	remaining: 3.16s
# 2855:	learn: 0.6821870	total: 1m 2s	remaining: 3.13s
# 2856:	learn: 0.6821796	total: 1m 2s	remaining: 3.11s
# 2857:	learn: 0.6821734	total: 1m 2s	remaining: 3.09s
# 2858:	learn: 0.6821680	total: 1m 2s	remaining: 3.07s
# 2859:	learn: 0.6821492	total: 1m 2s	remaining: 3.05s
# 2860:	learn: 0.6821298	total: 1m 2s	remaining: 3.02s
# 2861:	learn: 0.6821140	total: 1m 2s	remaining: 3s
# 2862:	learn: 0.6820832	total: 1m 2s	remaining: 2.98s
# 2863:	learn: 0.6820528	total: 1m 2s	remaining: 2.96s
# 2864:	learn: 0.6820208	total: 1m 2s	remaining: 2.94s
# 2865:	learn: 0.6820134	total: 1m 2s	remaining: 2.92s
# 2866:	learn: 0.6820020	total: 1m 2s	remaining: 2.9s
# 2867:	learn: 0.6819858	total: 1m 2s	remaining: 2.87s
# 2868:	learn: 0.6819699	total: 1m 2s	remaining: 2.85s
# 2869:	learn: 0.6819492	total: 1m 2s	remaining: 2.83s
# 2870:	learn: 0.6819349	total: 1m 2s	remaining: 2.81s
# 2871:	learn: 0.6819191	total: 1m 2s	remaining: 2.79s
# 2872:	learn: 0.6819103	total: 1m 2s	remaining: 2.76s
# 2873:	learn: 0.6819036	total: 1m 2s	remaining: 2.74s
# 2874:	learn: 0.6818634	total: 1m 2s	remaining: 2.72s
# 2875:	learn: 0.6818492	total: 1m 2s	remaining: 2.7s
# 2876:	learn: 0.6818333	total: 1m 2s	remaining: 2.68s
# 2877:	learn: 0.6818070	total: 1m 2s	remaining: 2.65s
# 2878:	learn: 0.6817795	total: 1m 2s	remaining: 2.63s
# 2879:	learn: 0.6817716	total: 1m 2s	remaining: 2.61s
# 2880:	learn: 0.6817589	total: 1m 2s	remaining: 2.59s
# 2881:	learn: 0.6817407	total: 1m 2s	remaining: 2.57s
# 2882:	learn: 0.6817344	total: 1m 2s	remaining: 2.55s
# 2883:	learn: 0.6817246	total: 1m 2s	remaining: 2.52s
# 2884:	learn: 0.6817070	total: 1m 2s	remaining: 2.5s
# 2885:	learn: 0.6816869	total: 1m 2s	remaining: 2.48s
# 2886:	learn: 0.6816716	total: 1m 2s	remaining: 2.46s
# 2887:	learn: 0.6816632	total: 1m 2s	remaining: 2.44s
# 2888:	learn: 0.6816456	total: 1m 2s	remaining: 2.42s
# 2889:	learn: 0.6816260	total: 1m 2s	remaining: 2.39s
# 2890:	learn: 0.6816106	total: 1m 2s	remaining: 2.37s
# 2891:	learn: 0.6816038	total: 1m 2s	remaining: 2.35s
# 2892:	learn: 0.6815879	total: 1m 2s	remaining: 2.33s
# 2893:	learn: 0.6815555	total: 1m 2s	remaining: 2.31s
# 2894:	learn: 0.6815259	total: 1m 3s	remaining: 2.29s
# 2895:	learn: 0.6815080	total: 1m 3s	remaining: 2.26s
# 2896:	learn: 0.6814964	total: 1m 3s	remaining: 2.24s
# 2897:	learn: 0.6814688	total: 1m 3s	remaining: 2.22s
# 2898:	learn: 0.6814490	total: 1m 3s	remaining: 2.2s
# 2899:	learn: 0.6814362	total: 1m 3s	remaining: 2.18s
# 2900:	learn: 0.6814093	total: 1m 3s	remaining: 2.15s
# 2901:	learn: 0.6813905	total: 1m 3s	remaining: 2.13s
# 2902:	learn: 0.6813708	total: 1m 3s	remaining: 2.11s
# 2903:	learn: 0.6813539	total: 1m 3s	remaining: 2.09s
# 2904:	learn: 0.6813402	total: 1m 3s	remaining: 2.07s
# 2905:	learn: 0.6813293	total: 1m 3s	remaining: 2.05s
# 2906:	learn: 0.6813051	total: 1m 3s	remaining: 2.02s
# 2907:	learn: 0.6812956	total: 1m 3s	remaining: 2s
# 2908:	learn: 0.6812644	total: 1m 3s	remaining: 1.98s
# 2909:	learn: 0.6812550	total: 1m 3s	remaining: 1.96s
# 2910:	learn: 0.6812422	total: 1m 3s	remaining: 1.94s
# 2911:	learn: 0.6812116	total: 1m 3s	remaining: 1.92s
# 2912:	learn: 0.6811719	total: 1m 3s	remaining: 1.89s
# 2913:	learn: 0.6811579	total: 1m 3s	remaining: 1.87s
# 2914:	learn: 0.6811436	total: 1m 3s	remaining: 1.85s
# 2915:	learn: 0.6811249	total: 1m 3s	remaining: 1.83s
# 2916:	learn: 0.6811068	total: 1m 3s	remaining: 1.81s
# 2917:	learn: 0.6810870	total: 1m 3s	remaining: 1.78s
# 2918:	learn: 0.6810738	total: 1m 3s	remaining: 1.76s
# 2919:	learn: 0.6810430	total: 1m 3s	remaining: 1.74s
# 2920:	learn: 0.6810198	total: 1m 3s	remaining: 1.72s
# 2921:	learn: 0.6810080	total: 1m 3s	remaining: 1.7s
# 2922:	learn: 0.6809925	total: 1m 3s	remaining: 1.68s
# 2923:	learn: 0.6809788	total: 1m 3s	remaining: 1.65s
# 2924:	learn: 0.6809679	total: 1m 3s	remaining: 1.63s
# 2925:	learn: 0.6809337	total: 1m 3s	remaining: 1.61s
# 2926:	learn: 0.6809229	total: 1m 3s	remaining: 1.59s
# 2927:	learn: 0.6809001	total: 1m 3s	remaining: 1.57s
# 2928:	learn: 0.6808877	total: 1m 3s	remaining: 1.54s
# 2929:	learn: 0.6808758	total: 1m 3s	remaining: 1.52s
# 2930:	learn: 0.6808630	total: 1m 3s	remaining: 1.5s
# 2931:	learn: 0.6808425	total: 1m 3s	remaining: 1.48s
# 2932:	learn: 0.6808334	total: 1m 3s	remaining: 1.46s
# 2933:	learn: 0.6808241	total: 1m 3s	remaining: 1.44s
# 2934:	learn: 0.6807946	total: 1m 3s	remaining: 1.41s
# 2935:	learn: 0.6807763	total: 1m 3s	remaining: 1.39s
# 2936:	learn: 0.6807556	total: 1m 3s	remaining: 1.37s
# 2937:	learn: 0.6807256	total: 1m 3s	remaining: 1.35s
# 2938:	learn: 0.6806903	total: 1m 3s	remaining: 1.33s
# 2939:	learn: 0.6806734	total: 1m 4s	remaining: 1.31s
# 2940:	learn: 0.6806551	total: 1m 4s	remaining: 1.28s
# 2941:	learn: 0.6806353	total: 1m 4s	remaining: 1.26s
# 2942:	learn: 0.6806285	total: 1m 4s	remaining: 1.24s
# 2943:	learn: 0.6806257	total: 1m 4s	remaining: 1.22s
# 2944:	learn: 0.6806068	total: 1m 4s	remaining: 1.2s
# 2945:	learn: 0.6805962	total: 1m 4s	remaining: 1.18s
# 2946:	learn: 0.6805852	total: 1m 4s	remaining: 1.15s
# 2947:	learn: 0.6805601	total: 1m 4s	remaining: 1.13s
# 2948:	learn: 0.6805538	total: 1m 4s	remaining: 1.11s
# 2949:	learn: 0.6805431	total: 1m 4s	remaining: 1.09s
# 2950:	learn: 0.6805394	total: 1m 4s	remaining: 1.07s
# 2951:	learn: 0.6805028	total: 1m 4s	remaining: 1.04s
# 2952:	learn: 0.6804740	total: 1m 4s	remaining: 1.02s
# 2953:	learn: 0.6804512	total: 1m 4s	remaining: 1s
# 2954:	learn: 0.6804381	total: 1m 4s	remaining: 980ms
# 2955:	learn: 0.6804267	total: 1m 4s	remaining: 958ms
# 2956:	learn: 0.6803813	total: 1m 4s	remaining: 936ms
# 2957:	learn: 0.6803759	total: 1m 4s	remaining: 914ms
# 2958:	learn: 0.6803375	total: 1m 4s	remaining: 892ms
# 2959:	learn: 0.6803182	total: 1m 4s	remaining: 871ms
# 2960:	learn: 0.6802957	total: 1m 4s	remaining: 849ms
# 2961:	learn: 0.6802710	total: 1m 4s	remaining: 827ms
# 2962:	learn: 0.6802565	total: 1m 4s	remaining: 805ms
# 2963:	learn: 0.6802413	total: 1m 4s	remaining: 784ms
# 2964:	learn: 0.6802208	total: 1m 4s	remaining: 762ms
# 2965:	learn: 0.6802128	total: 1m 4s	remaining: 740ms
# 2966:	learn: 0.6801980	total: 1m 4s	remaining: 718ms
# 2967:	learn: 0.6801807	total: 1m 4s	remaining: 697ms
# 2968:	learn: 0.6801728	total: 1m 4s	remaining: 675ms
# 2969:	learn: 0.6801585	total: 1m 4s	remaining: 653ms
# 2970:	learn: 0.6801537	total: 1m 4s	remaining: 631ms
# 2971:	learn: 0.6801221	total: 1m 4s	remaining: 609ms
# 2972:	learn: 0.6801080	total: 1m 4s	remaining: 588ms
# 2973:	learn: 0.6800982	total: 1m 4s	remaining: 566ms
# 2974:	learn: 0.6800743	total: 1m 4s	remaining: 544ms
# 2975:	learn: 0.6800444	total: 1m 4s	remaining: 522ms
# 2976:	learn: 0.6800333	total: 1m 4s	remaining: 501ms
# 2977:	learn: 0.6800117	total: 1m 4s	remaining: 479ms
# 2978:	learn: 0.6799770	total: 1m 4s	remaining: 457ms
# 2979:	learn: 0.6799647	total: 1m 4s	remaining: 435ms
# 2980:	learn: 0.6799356	total: 1m 4s	remaining: 414ms
# 2981:	learn: 0.6799271	total: 1m 4s	remaining: 392ms
# 2982:	learn: 0.6799208	total: 1m 4s	remaining: 370ms
# 2983:	learn: 0.6799135	total: 1m 4s	remaining: 348ms
# 2984:	learn: 0.6798914	total: 1m 4s	remaining: 326ms
# 2985:	learn: 0.6798821	total: 1m 4s	remaining: 305ms
# 2986:	learn: 0.6798532	total: 1m 5s	remaining: 283ms
# 2987:	learn: 0.6798511	total: 1m 5s	remaining: 261ms
# 2988:	learn: 0.6798340	total: 1m 5s	remaining: 239ms
# 2989:	learn: 0.6798021	total: 1m 5s	remaining: 218ms
# 2990:	learn: 0.6797693	total: 1m 5s	remaining: 196ms
# 2991:	learn: 0.6797586	total: 1m 5s	remaining: 174ms
# 2992:	learn: 0.6797457	total: 1m 5s	remaining: 152ms
# 2993:	learn: 0.6797424	total: 1m 5s	remaining: 131ms
# 2994:	learn: 0.6797240	total: 1m 5s	remaining: 109ms
# 2995:	learn: 0.6797147	total: 1m 5s	remaining: 87ms
# 2996:	learn: 0.6797029	total: 1m 5s	remaining: 65.3ms
# 2997:	learn: 0.6796766	total: 1m 5s	remaining: 43.5ms
# 2998:	learn: 0.6796560	total: 1m 5s	remaining: 21.8ms
# 2999:	learn: 0.6796356	total: 1m 5s	remaining: 0us

# %% [markdown]
# Создадим файл для отправки

# %%
def make_submission_3m(model):
    sample_submission_df = pd.read_csv("sample_submission.csv")
    test_df["date"] == "month_6"
    try:
        test_pred_proba = model.predict_proba(X_test_lda)
    except:
        test_pred_proba = model.predict(X_test_lda)
    test_pred_proba /= test_pred_proba.sum(axis=1).reshape(-1, 1)
    test_pred_proba_df = pd.DataFrame(test_pred_proba, columns=labels)
    sorted_classes = sorted(test_pred_proba_df.columns.to_list())
    test_pred_proba_df = test_pred_proba_df[sorted_classes]

    sample_submission_df[sorted_classes] = test_pred_proba_df
    sample_submission_df.to_csv("vitya.csv", index=False)


make_submission_3m(model)
